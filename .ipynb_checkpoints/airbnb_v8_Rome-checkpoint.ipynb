# %% [markdown]
# <a id="0.1"></a>
# <h1 style="background-color:#38ACEC;font-family:newtimeroman;font-size:350%;text-align:center;border-radius: 15px 50px;">Inhaltsverzeichnis</h1>
#
# * [1. Einführung](#1)
#     * [1.1 Datenquelle](#1.1)
#     * [1.2 Anforderungen](#1.2)
#     * [1.3 Datensatz und Datenwörterbuch](#1.3)
#     * [1.4 Einlesen der Daten](#1.4)
# * [2. Exploratory Data Analysis](#2)
#     * [2.2 Datenüberblick: Einheiten, Missing-Rate, Anzahl eindeutiger Werte](#2.2)
#     * [2.3 Deskriptive statistik: Min/Max/Median/Mean, Ausreißer](#2.3)
#     * [2.4 Drop-Kandidaten Analyse](#2.4)
#     * [2.5 Numerische Spalten](#2.5)
#     * [2.6 Kategoriale Spalten](#2.6)
#     * [2.7 Boolesche Spalten](#2.7)
#     * [2.8 Datums-Spalten](#2.8)
# * [3. Bereinigen Der Daten](#3)
#     * [3.1 Fehlende Werte füllen](#3.1)
#     * [3.2 Drop-Kandidaten löschen](#3.2)
# * [4. Daten zusammenfassen und speichern](#4)
#     * [4.1 Daten zusammenfassen](#4.1)
#     * [4.2 Daten speichern](#4.2)

# %% [markdown]
# <a class="anchor" id="1.1"></a>
# <h3 style="background-color:#38ACEC;font-family:newtimeroman;font-size:180%;text-align:center;border-radius: 15px 50px;">1.1 Datenquelle</h3>
#
# **Inside Airbnb** ist ein gemeinwohlorientiertes Projekt. Es sammelt Daten zu Airbnb zur Analyse der Wirkung auf *Wohngebiete*.
# *[_About – Inside Airbnb_](https://insideairbnb.com/about/)*
#
# Daten Details:
# - Die Daten nutzen öffentlich zugängliche Informationen, die von der Airbnb-Website zusammengetragen wurden, einschließlich des Verfügbarkeitskalenders
# für 365 Tage in der Zukunft sowie der Bewertungen zu jedem Inserat.
# - Es werden keine „privaten“ Informationen verwendet. Namen, Fotos, Inserate und Bewertungsdetails werden sämtlich öffentlich auf der Airbnb-Website
# angezeigt.
# - Standortinformationen zu Inseraten werden von Airbnb anonymisiert. In der Praxis bedeutet das, dass der in der Karte bzw. in den Daten
# angegebene Standort eines Inserats bis zu 150 Meter vom tatsächlichen Adresspunkt verschoben ist.
# - Die hier präsentierten Daten sind eine Momentaufnahme der zu einem bestimmten Zeitpunkt verfügbaren Inserate.
# Der Airbnb-Kalender für ein Inserat unterscheidet nicht zwischen einer gebuchten Nacht und einer aus anderen Gründen nicht verfügbaren Nacht; daher werden solche Nächte als „nicht verfügbar“ gezählt. Das führt dazu, dass die Kennzahl zur Verfügbarkeit tendenziell unterschätzt wird, weil beliebte Inserate eher „gebucht“ sind, als dass sie vom Host „gesperrt“ werden.
# Einige Hosts pflegen ihren Kalender möglicherweise nicht aktuell oder halten ihn sehr weitgehend offen, obwohl sie die gesamte Wohnung bzw. das gesamte Haus selbst bewohnen.
# - Die Viertelnamen für jedes Inserat werden ermittelt, indem die geografischen Koordinaten des Inserats mit der städtischen Definition
# der Viertel abgeglichen werden. Die von Airbnb vergebenen Viertelnamen werden aufgrund ihrer Ungenauigkeiten nicht verwendet.
#
# [**Inhaltsverzeichnis**](#0.1)

# %% [markdown]
# <a class="anchor" id="1.2"></a>
# <h3 style="background-color:#38ACEC;font-family:newtimeroman;font-size:180%;text-align:center;border-radius: 15px 50px;">1.2 Anforderungen</h3>
#
#
# **Liste der erforderlichen Bibliotheken:**
# - *`pandas`* — Daten laden, aufbereiten, zusammenfassen
# - *`numpy`* — Numerische Daten aufbereiten
# - *`re`* — Funktionen zur Arbeit mit regulären Ausdrücken
#
#
# [**Inhaltsverzeichnis**](#0.1)

# %%
import re

import numpy as np
import pandas as pd

# %% [markdown]
# <a class="anchor" id="1.3"></a>
# <h3 style="background-color:#38ACEC;font-family:newtimeroman;font-size:180%;text-align:center;border-radius: 15px 50px;">1.3 Datensatz & Datenwörterbuch</h3>
#
#
# - **Stadt:** New York City, New York, USA
# - **Datei:** `listings_big.csv.gz` — *Detailed Listings*
# - **Daten-Seite:** *[_Get the Data_](https://insideairbnb.com/get-the-data/)*
# - **Datenwörterbuch:** *[Inside Airbnb Data Dictionary (Google Sheet)](https://docs.google.com/spreadsheets/d/1iWCNJcSutYqpULSQHlNyGInUvHg2BoUGoNRIGa6Szc4/edit?gid=1322284596#gid=1322284596)*
#
# [**Inhaltsverzeichnis**](#0.1)

# %% [markdown]
# <a class="anchor" id="2.1"></a>
# <h3 style="background-color:#38ACEC;font-family:newtimeroman;font-size:180%;text-align:center;border-radius: 15px 50px;">2.1 Einlesen der Daten</h3>
#
#
# [**Inhaltsverzeichnis**](#0.1)

# %%
file = "data/12/NewYorkCity/listings_big.csv" 

df_orig = pd.read_csv(file, low_memory=False)

# Anzahl Zeilen und Spalten
df_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36322 entries, 0 to 36321
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            36322 non-null  int64
#  1   listing_url                                   36322 non-null  object
#  2   scrape_id                                     36322 non-null  int64
#  3   last_scraped                                  36322 non-null  object
#  4   source                                        36322 non-null  object
#  5   name                                          36320 non-null  object
#  6   description                                   35374 non-null  object
#  7   neighborhood_overview                         19084 non-null  object
#  8   picture_url                                   36322 non-null  object
#  9   host_id                                       36322 non-null  int64
#  10  host_url                                      36322 non-null  object
#  11  host_name                                     36307 non-null  object
#  12  host_since                                    36307 non-null  object
#  13  host_location                                 28913 non-null  object
#  14  host_about                                    20956 non-null  object
#  15  host_response_time                            21550 non-null  object
#  16  host_response_rate                            21550 non-null  object
#  17  host_acceptance_rate                          21720 non-null  object
#  18  host_is_superhost                             35830 non-null  object
#  19  host_thumbnail_url                            36307 non-null  object
#  20  host_picture_url                              36307 non-null  object
#  21  host_neighbourhood                            29034 non-null  object
#  22  host_listings_count                           36307 non-null  float64
#  23  host_total_listings_count                     36307 non-null  float64
#  24  host_verifications                            36307 non-null  object
#  25  host_has_profile_pic                          36307 non-null  object
#  26  host_identity_verified                        36307 non-null  object
#  27  neighbourhood                                 19085 non-null  object
#  28  neighbourhood_cleansed                        36322 non-null  object
#  29  neighbourhood_group_cleansed                  36322 non-null  object
#  30  latitude                                      36322 non-null  float64
#  31  longitude                                     36322 non-null  float64
#  32  property_type                                 36322 non-null  object
#  33  room_type                                     36322 non-null  object
#  34  accommodates                                  36322 non-null  int64
#  35  bathrooms                                     21682 non-null  float64
#  36  bathrooms_text                                36286 non-null  object
#  37  bedrooms                                      30274 non-null  float64
#  38  beds                                          21620 non-null  float64
#  39  amenities                                     36322 non-null  object
#  40  price                                         21459 non-null  object
#  41  minimum_nights                                36322 non-null  int64
#  42  maximum_nights                                36322 non-null  int64
#  43  minimum_minimum_nights                        36322 non-null  int64
#  44  maximum_minimum_nights                        36322 non-null  int64
#  45  minimum_maximum_nights                        36322 non-null  int64
#  46  maximum_maximum_nights                        36322 non-null  int64
#  47  minimum_nights_avg_ntm                        36322 non-null  float64
#  48  maximum_nights_avg_ntm                        36322 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              30705 non-null  object
#  51  availability_30                               36322 non-null  int64
#  52  availability_60                               36322 non-null  int64
#  53  availability_90                               36322 non-null  int64
#  54  availability_365                              36322 non-null  int64
#  55  calendar_last_scraped                         36322 non-null  object
#  56  number_of_reviews                             36322 non-null  int64
#  57  number_of_reviews_ltm                         36322 non-null  int64
#  58  number_of_reviews_l30d                        36322 non-null  int64
#  59  availability_eoy                              36322 non-null  int64
#  60  number_of_reviews_ly                          36322 non-null  int64
#  61  estimated_occupancy_l365d                     36322 non-null  int64
#  62  estimated_revenue_l365d                       21459 non-null  float64
#  63  first_review                                  25171 non-null  object
#  64  last_review                                   25171 non-null  object
#  65  review_scores_rating                          25171 non-null  float64
#  66  review_scores_accuracy                        25161 non-null  float64
#  67  review_scores_cleanliness                     25170 non-null  float64
#  68  review_scores_checkin                         25157 non-null  float64
#  69  review_scores_communication                   25165 non-null  float64
#  70  review_scores_location                        25154 non-null  float64
#  71  review_scores_value                           25155 non-null  float64
#  72  license                                       5329 non-null   object
#  73  instant_bookable                              36322 non-null  object
#  74  calculated_host_listings_count                36322 non-null  int64
#  75  calculated_host_listings_count_entire_homes   36322 non-null  int64
#  76  calculated_host_listings_count_private_rooms  36322 non-null  int64
#  77  calculated_host_listings_count_shared_rooms   36322 non-null  int64
#  78  reviews_per_month                             25171 non-null  float64
# dtypes: float64(19), int64(24), object(36)
# memory usage: 21.9+ MB

# %% [markdown]
# <a class="anchor" id="2.2"></a>
# <h3 style="background-color:blue;font-family:newtimeroman;font-size:180%;text-align:center;border-radius: 15px 50px;">2. Exploratory Data Analysis</h3>

# %%
# Anzahl Numerische Spalten
df_orig.select_dtypes(include="number").shape[1]
# Out:
# 43

# %%
# Anzahl Kategoriale Spalten
df_orig.select_dtypes(include=["object"]).shape[1]
# Out:
# 36

# %% [markdown]
# <a class="anchor" id="2.1"></a>
# <h3 style="background-color:#38ACEC;font-family:newtimeroman;font-size:180%;text-align:center;border-radius: 15px 50px;">2.1 Datenüberblick: Einheiten, Missing-Rate, Anzahl eindeutiger Werte</h3>
#
#
# [**Inhaltsverzeichnis**](#0.1)

# %%
print("Anzahl Zeilen, Anzahl Spalten: ", df_orig.shape)
# Out:
# Anzahl Zeilen, Anzahl Spalten:  (36322, 79)

# %%
if len(df_orig["id"].unique()) == df_orig.shape[0]:
    print("Spalte \"id\" ist unique Idendifikator")
# Out:
# Spalte "id" ist unique Idendifikator

# %% [markdown]
# | **Abschnitt**                                         | **Beschreibung**                                                | **Spalten (Felder)**                                                                                                                                                                                                                                                                                                                                                                         | **Einheiten / Hinweise (laut Data Dictionary)**                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# | ----------------------------------------------------- | --------------------------------------------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **Zeitebene**                                         | Momentaufnahme (Snapshot) des Bestands zum Erfassungszeitpunkt. | `last_scraped`                                                                                                                                                                                                                                                                                                                                                                               | **Datetime (UTC)** – Zeitpunkt, an dem das Listing „gescraped“ wurde.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# | **Analyse-Einheiten (Granularität)**                  | Ebenen, auf denen ausgewertet/aggregiert wird.                  | Listing: `id` • Host: `host_id` • Nachbarschaft: `neighbourhood_cleansed`, `neighbourhood_group_cleansed` • Zeit: `host_since`, `first_review`, `last_review`                                                                                                                                                                                                                                | `id` (**integer**) = eindeutige Listing-ID • `host_id` (**integer**) = Host-ID • `host_since` (**date**) = Konto-Erstellungsdatum • `first_review`/`last_review` (**date**) = erste/letzte Rezension.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# | **Wichtige Maßeinheiten (Markt/Qualität)**            | Zentrale Messgrößen je Listing.                                 | **Preis:** `price` • **Verfügbarkeit:** `availability_30`, `availability_60`, `availability_90`, `availability_365`, `has_availability` • **Bewertungen:** `number_of_reviews`, `reviews_per_month`, `review_scores_*` • **Kapazität/Ausstattung:** `accommodates`, `bedrooms`, `beds`, `bathrooms`, `bathrooms_text` • **Buchung:** `instant_bookable`                                      | `price` (**currency**) = täglicher Preis in **lokaler Währung**; **\$** im Export ist ein technisches Artefakt (ignorieren). • `availability_x` (**integer**) = verfügbare Nächte in den nächsten **x** Tagen; „nicht verfügbar“ kann **gebucht** oder **geblockt** bedeuten. • `has_availability` (**boolean**) = **t/f**. • `number_of_reviews` (**integer**). • `reviews_per_month` = Durchschnitt **Rezensionen/Monat** über die Lebenszeit (vgl. Pseudocode im Dictionary). • `review_scores_*` (numerisch, Airbnb-Scores). • `accommodates` (**integer**) = Gäste. • `bathrooms` (**numeric**), `bathrooms_text` (**string**, textuelle Angabe, z. B. „1.5 shared baths“). • `instant_bookable` (**boolean**) = **t/f**, ob automatische Buchung möglich ist. |
# | **Listing-Ebene – Kernmetriken**                      | Attribute pro Inserat (Anzeige).                                          | `property_type`, `room_type`, `accommodates`, `bedrooms`, `beds`, `bathrooms`/`bathrooms_text`, `price`, `has_availability`, `availability_30/60/90/365`, `number_of_reviews`, `reviews_per_month`, `review_scores_*`, `instant_bookable`, `host_is_superhost`, `host_listings_count`, `host_since`, Lage: `neighbourhood_cleansed`, `neighbourhood_group_cleansed`, `latitude`, `longitude` | Typen laut Dictionary: `property_type`, `room_type`, `neighbourhood_*` (**text**); `latitude`/`longitude` (**numeric**); `host_is_superhost` (**boolean**, **t/f**); `host_listings_count` (**integer**).                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# | **Abgeleitete Kennzahlen (nützlich, nicht original)** | Aus Rohfeldern berechnet (für Analysen).                        | `occupied_nights_365`, `revpar_proxy`, `price_per_guest`, `host_tenure_days`                                                                                                                                                                                                                                                                                                                 | **Belegte Nächte (Proxy):** `occupied_nights_365 = 365 − availability_365` (Nächte/Jahr) • **RevPAR (Proxy):** `estimated_revenue_l365d / 365` • **Preis/Gast:** `price / accommodates` • **Host-Tenure (Tage):** `last_scraped − host_since`.                                                                                                                                                                                                                                                                                                                                                                                                                                                       |

# %%
# Daten Verständnis:

# Drop Spälte mit reine URLs, Bilder, Host Name, Host-ID, Host Location, Bescreibung

# Spalte rehalten Info über lätzte Scrape
# calculated_host_listings_count 
# calculated_host_listings_count_entire_homes 
# calculated_host_listings_count_private_rooms 
# calculated_host_listings_count_shared_rooms 

# Spalte "host_name" - Name of the host. Usually just the first name(s).

# Spalten "host_listings_count", "host_total_listings_count": The number of listings the host has (per Airbnb unknown calculations)

# Spalte brauche für Analyse nicht:
drop_columns = ["listing_url", 
                "scrape_id", 
                "last_scraped", 
                "source",
                "description",
                "neighborhood_overview", 
                "picture_url",
                "host_url",
                "host_name",
                "host_about",
                "host_thumbnail_url",
                "host_picture_url",
                "host_listings_count",
                "host_total_listings_count",
                "host_has_profile_pic",
                "calendar_last_scraped",
                "calculated_host_listings_count",
                "calculated_host_listings_count_entire_homes",
                "calculated_host_listings_count_private_rooms",
                "calculated_host_listings_count_shared_rooms"
                ]

df = df_orig.drop(columns=drop_columns, axis=1, errors="ignore")

# %%
# Zusätchlive Funktionen

# Missing Values
missing = df.isnull().sum().to_frame()

def missing_values(df):
    missing["Missing_values"] = df.isnull().sum().to_frame()
    missing["Total_perc"] = (missing["Missing_values"] / len(df)) * 100
    return missing

# %%
missing_values(df)[missing["Total_perc"] > 0].Total_perc
# Out:
# name                             0.005506
# host_since                       0.041297
# host_location                   20.398106
# host_response_time              40.669567
# host_response_rate              40.669567
# host_acceptance_rate            40.201531
# host_is_superhost                1.354551
# host_neighbourhood              20.064974
# host_verifications               0.041297
# host_identity_verified           0.041297
# neighbourhood                   47.456087
# bathrooms                       40.306151
# bathrooms_text                   0.099113
# bedrooms                        16.651065
# beds                            40.476846
# price                           40.920104
# calendar_updated               100.000000
# has_availability                15.464457
# estimated_revenue_l365d         40.920104
# first_review                    30.700402
# last_review                     30.700402
# review_scores_rating            30.700402
# review_scores_accuracy          30.727933
# review_scores_cleanliness       30.703155
# review_scores_checkin           30.738946
# review_scores_communication     30.716921
# review_scores_location          30.747206
# review_scores_value             30.744452
# license                         85.328451
# reviews_per_month               30.700402
# Name: Total_perc, dtype: float64

# %%
# Spalte: "calendar_updated" Missing-Rate 100%
df["calendar_updated"].unique()

# Spalte "neighbourhood" has nur zwei Werte: ['Neighborhood highlights', nan]
df["neighbourhood"].unique()

# Missing-Rate > 40% and no description in the data Doctionary:
# host_is_superhost 
# host_response_time
# host_response_rate
# Out:
# array(['Neighborhood highlights', nan], dtype=object)

# %%
drop_columns = ["host_response_time",
                "host_response_rate",
                "host_is_superhost",
                "neighbourhood",
                "calendar_updated",
                ]

df = df.drop(columns=drop_columns, axis=1, errors="ignore")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36322 entries, 0 to 36321
# Data columns (total 54 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            36322 non-null  int64
#  1   name                          36320 non-null  object
#  2   host_id                       36322 non-null  int64
#  3   host_since                    36307 non-null  object
#  4   host_location                 28913 non-null  object
#  5   host_acceptance_rate          21720 non-null  object
#  6   host_neighbourhood            29034 non-null  object
#  7   host_verifications            36307 non-null  object
#  8   host_identity_verified        36307 non-null  object
#  9   neighbourhood_cleansed        36322 non-null  object
#  10  neighbourhood_group_cleansed  36322 non-null  object
#  11  latitude                      36322 non-null  float64
#  12  longitude                     36322 non-null  float64
#  13  property_type                 36322 non-null  object
#  14  room_type                     36322 non-null  object
#  15  accommodates                  36322 non-null  int64
#  16  bathrooms                     21682 non-null  float64
#  17  bathrooms_text                36286 non-null  object
#  18  bedrooms                      30274 non-null  float64
#  19  beds                          21620 non-null  float64
#  20  amenities                     36322 non-null  object
#  21  price                         21459 non-null  object
#  22  minimum_nights                36322 non-null  int64
#  23  maximum_nights                36322 non-null  int64
#  24  minimum_minimum_nights        36322 non-null  int64
#  25  maximum_minimum_nights        36322 non-null  int64
#  26  minimum_maximum_nights        36322 non-null  int64
#  27  maximum_maximum_nights        36322 non-null  int64
#  28  minimum_nights_avg_ntm        36322 non-null  float64
#  29  maximum_nights_avg_ntm        36322 non-null  float64
#  30  has_availability              30705 non-null  object
#  31  availability_30               36322 non-null  int64
#  32  availability_60               36322 non-null  int64
#  33  availability_90               36322 non-null  int64
#  34  availability_365              36322 non-null  int64
#  35  number_of_reviews             36322 non-null  int64
#  36  number_of_reviews_ltm         36322 non-null  int64
#  37  number_of_reviews_l30d        36322 non-null  int64
#  38  availability_eoy              36322 non-null  int64
#  39  number_of_reviews_ly          36322 non-null  int64
#  40  estimated_occupancy_l365d     36322 non-null  int64
#  41  estimated_revenue_l365d       21459 non-null  float64
#  42  first_review                  25171 non-null  object
#  43  last_review                   25171 non-null  object
#  44  review_scores_rating          25171 non-null  float64
#  45  review_scores_accuracy        25161 non-null  float64
#  46  review_scores_cleanliness     25170 non-null  float64
#  47  review_scores_checkin         25157 non-null  float64
#  48  review_scores_communication   25165 non-null  float64
#  49  review_scores_location        25154 non-null  float64
#  50  review_scores_value           25155 non-null  float64
#  51  license                       5329 non-null   object
#  52  instant_bookable              36322 non-null  object
#  53  reviews_per_month             25171 non-null  float64
# dtypes: float64(16), int64(19), object(19)
# memory usage: 15.0+ MB
# None

# %%
# Spalte "license" - Werte [nan, 'Exempt', "OSE-*"]
# Spalte "license" nicht droppen
[i for i in df_orig["license"].unique() if str(i)[:4].upper() != "OSE-"]
# Out:
# [nan, 'Exempt']

# %% [markdown]
# <a class="anchor" id="2.2"></a>
# <h3 style="background-color:#38ACEC;font-family:newtimeroman;font-size:180%;text-align:center;border-radius: 15px 50px;">2.2 Deskriptive statistik: Min/Max/Median/Mean, Ausreißer</h3>
#
# [**Inhaltsverzeichnis**](#0.1)

# %%
#Check for the missing values

df.isna().any()
# Out:
# id                              False
# name                             True
# host_id                         False
# host_since                       True
# host_location                    True
# host_acceptance_rate             True
# host_neighbourhood               True
# host_verifications               True
# host_identity_verified           True
# neighbourhood_cleansed          False
# neighbourhood_group_cleansed    False
# latitude                        False
# longitude                       False
# property_type                   False
# room_type                       False
# accommodates                    False
# bathrooms                        True
# bathrooms_text                   True
# bedrooms                         True
# beds                             True
# amenities                       False
# price                            True
# minimum_nights                  False
# maximum_nights                  False
# minimum_minimum_nights          False
# maximum_minimum_nights          False
# minimum_maximum_nights          False
# maximum_maximum_nights          False
# minimum_nights_avg_ntm          False
# maximum_nights_avg_ntm          False
# has_availability                 True
# availability_30                 False
# availability_60                 False
# availability_90                 False
# availability_365                False
# number_of_reviews               False
# number_of_reviews_ltm           False
# number_of_reviews_l30d          False
# availability_eoy                False
# number_of_reviews_ly            False
# estimated_occupancy_l365d       False
# estimated_revenue_l365d          True
# first_review                     True
# last_review                      True
# review_scores_rating             True
# review_scores_accuracy           True
# review_scores_cleanliness        True
# review_scores_checkin            True
# review_scores_communication      True
# review_scores_location           True
# review_scores_value              True
# license                          True
# instant_bookable                False
# reviews_per_month                True
# dtype: bool

# %%
#Calculating the percentage of missing values

missing_values(df_orig)[missing["Total_perc"] > 0].Total_perc
# Out:
# name                             0.005506
# host_since                       0.041297
# host_location                   20.398106
# host_response_time              40.669567
# host_response_rate              40.669567
# host_acceptance_rate            40.201531
# host_is_superhost                1.354551
# host_neighbourhood              20.064974
# host_verifications               0.041297
# host_identity_verified           0.041297
# neighbourhood                   47.456087
# bathrooms                       40.306151
# bathrooms_text                   0.099113
# bedrooms                        16.651065
# beds                            40.476846
# price                           40.920104
# calendar_updated               100.000000
# has_availability                15.464457
# estimated_revenue_l365d         40.920104
# first_review                    30.700402
# last_review                     30.700402
# review_scores_rating            30.700402
# review_scores_accuracy          30.727933
# review_scores_cleanliness       30.703155
# review_scores_checkin           30.738946
# review_scores_communication     30.716921
# review_scores_location          30.747206
# review_scores_value             30.744452
# license                         85.328451
# reviews_per_month               30.700402
# Name: Total_perc, dtype: float64

# %%
# Mean of the Columns "accommodates"

df["accommodates"].mean().round(2)
# Out:
# np.float64(2.75)

# %%
# Mean of the Columns "minimum_nights", "maximum_nights"

df["minimum_nights"].mean().round(2), df["maximum_nights"].mean().round(2)
# Out:
# (np.float64(29.21), np.float64(60243.92))

# %%
# Max value per column

df.max(numeric_only=True)
# Out:
# id                             1.444534e+18
# host_id                        7.005911e+08
# latitude                       4.091139e+01
# longitude                     -7.371182e+01
# accommodates                   1.600000e+01
# bathrooms                      1.550000e+01
# bedrooms                       1.500000e+01
# beds                           4.000000e+01
# minimum_nights                 1.124000e+03
# maximum_nights                 2.147484e+09
# minimum_minimum_nights         1.124000e+03
# maximum_minimum_nights         1.124000e+03
# minimum_maximum_nights         2.147484e+09
# maximum_maximum_nights         2.147484e+09
# minimum_nights_avg_ntm         1.124000e+03
# maximum_nights_avg_ntm         2.147484e+09
# availability_30                3.000000e+01
# availability_60                6.000000e+01
# availability_90                9.000000e+01
# availability_365               3.650000e+02
# number_of_reviews              3.277000e+03
# number_of_reviews_ltm          1.786000e+03
# number_of_reviews_l30d         1.530000e+02
# availability_eoy               1.980000e+02
# number_of_reviews_ly           1.797000e+03
# estimated_occupancy_l365d      2.550000e+02
# estimated_revenue_l365d        1.275000e+07
# review_scores_rating           5.000000e+00
# review_scores_accuracy         5.000000e+00
# review_scores_cleanliness      5.000000e+00
# review_scores_checkin          5.000000e+00
# review_scores_communication    5.000000e+00
# review_scores_location         5.000000e+00
# review_scores_value            5.000000e+00
# reviews_per_month              1.219700e+02
# dtype: float64

# %%
# Min value per column

df.min(numeric_only=True)
# Out:
# id                             2539.000000
# host_id                        1678.000000
# latitude                         40.500366
# longitude                       -74.251907
# accommodates                      1.000000
# bathrooms                         0.000000
# bedrooms                          0.000000
# beds                              0.000000
# minimum_nights                    1.000000
# maximum_nights                    1.000000
# minimum_minimum_nights            1.000000
# maximum_minimum_nights            1.000000
# minimum_maximum_nights            1.000000
# maximum_maximum_nights            1.000000
# minimum_nights_avg_ntm            1.000000
# maximum_nights_avg_ntm            1.000000
# availability_30                   0.000000
# availability_60                   0.000000
# availability_90                   0.000000
# availability_365                  0.000000
# number_of_reviews                 0.000000
# number_of_reviews_ltm             0.000000
# number_of_reviews_l30d            0.000000
# availability_eoy                  0.000000
# number_of_reviews_ly              0.000000
# estimated_occupancy_l365d         0.000000
# estimated_revenue_l365d           0.000000
# review_scores_rating              0.000000
# review_scores_accuracy            0.000000
# review_scores_cleanliness         0.000000
# review_scores_checkin             0.000000
# review_scores_communication       0.000000
# review_scores_location            0.000000
# review_scores_value               0.000000
# reviews_per_month                 0.010000
# dtype: float64

# %%
# Median
df.median(numeric_only=True)
# Out:
# id                             5.004978e+07
# host_id                        8.336440e+07
# latitude                       4.072594e+01
# longitude                     -7.395471e+01
# accommodates                   2.000000e+00
# bathrooms                      1.000000e+00
# bedrooms                       1.000000e+00
# beds                           1.000000e+00
# minimum_nights                 3.000000e+01
# maximum_nights                 3.650000e+02
# minimum_minimum_nights         3.000000e+01
# maximum_minimum_nights         3.000000e+01
# minimum_maximum_nights         3.650000e+02
# maximum_maximum_nights         7.300000e+02
# minimum_nights_avg_ntm         3.000000e+01
# maximum_nights_avg_ntm         5.791000e+02
# availability_30                0.000000e+00
# availability_60                7.000000e+00
# availability_90                2.600000e+01
# availability_365               1.530000e+02
# number_of_reviews              3.000000e+00
# number_of_reviews_ltm          0.000000e+00
# number_of_reviews_l30d         0.000000e+00
# availability_eoy               8.500000e+01
# number_of_reviews_ly           0.000000e+00
# estimated_occupancy_l365d      0.000000e+00
# estimated_revenue_l365d        0.000000e+00
# review_scores_rating           4.860000e+00
# review_scores_accuracy         4.900000e+00
# review_scores_cleanliness      4.810000e+00
# review_scores_checkin          4.950000e+00
# review_scores_communication    4.960000e+00
# review_scores_location         4.850000e+00
# review_scores_value            4.760000e+00
# reviews_per_month              2.600000e-01
# dtype: float64

# %%
# Standard Deviation
df.std(numeric_only=True)
# Out:
# id                             5.199100e+17
# host_id                        1.893709e+08
# latitude                       5.648223e-02
# longitude                      5.525153e-02
# accommodates                   1.891702e+00
# bathrooms                      5.544393e-01
# bedrooms                       9.381921e-01
# beds                           1.193949e+00
# minimum_nights                 3.511100e+01
# maximum_nights                 1.126843e+07
# minimum_minimum_nights         3.496167e+01
# maximum_minimum_nights         6.464567e+01
# minimum_maximum_nights         2.519472e+07
# maximum_maximum_nights         4.363228e+07
# minimum_nights_avg_ntm         3.757597e+01
# maximum_nights_avg_ntm         3.055266e+07
# availability_30                1.180300e+01
# availability_60                2.406532e+01
# availability_90                3.606974e+01
# availability_365               1.455351e+02
# number_of_reviews              6.738206e+01
# number_of_reviews_ltm          2.008151e+01
# number_of_reviews_l30d         1.483196e+00
# availability_eoy               8.021589e+01
# number_of_reviews_ly           1.911530e+01
# estimated_occupancy_l365d      8.546655e+01
# estimated_revenue_l365d        9.763701e+04
# review_scores_rating           4.508312e-01
# review_scores_accuracy         4.377228e-01
# review_scores_cleanliness      4.999087e-01
# review_scores_checkin          3.758870e-01
# review_scores_communication    4.155085e-01
# review_scores_location         3.895678e-01
# review_scores_value            4.918495e-01
# reviews_per_month              1.850794e+00
# dtype: float64

# %%
# Variance
df.var(numeric_only=True)
# Out:
# id                             2.703064e+35
# host_id                        3.586133e+16
# latitude                       3.190243e-03
# longitude                      3.052732e-03
# accommodates                   3.578536e+00
# bathrooms                      3.074030e-01
# bedrooms                       8.802045e-01
# beds                           1.425515e+00
# minimum_nights                 1.232783e+03
# maximum_nights                 1.269776e+14
# minimum_minimum_nights         1.222318e+03
# maximum_minimum_nights         4.179063e+03
# minimum_maximum_nights         6.347741e+14
# maximum_maximum_nights         1.903776e+15
# minimum_nights_avg_ntm         1.411954e+03
# maximum_nights_avg_ntm         9.334651e+14
# availability_30                1.393109e+02
# availability_60                5.791395e+02
# availability_90                1.301026e+03
# availability_365               2.118047e+04
# number_of_reviews              4.540342e+03
# number_of_reviews_ltm          4.032669e+02
# number_of_reviews_l30d         2.199869e+00
# availability_eoy               6.434589e+03
# number_of_reviews_ly           3.653948e+02
# estimated_occupancy_l365d      7.304531e+03
# estimated_revenue_l365d        9.532985e+09
# review_scores_rating           2.032488e-01
# review_scores_accuracy         1.916012e-01
# review_scores_cleanliness      2.499087e-01
# review_scores_checkin          1.412910e-01
# review_scores_communication    1.726474e-01
# review_scores_location         1.517631e-01
# review_scores_value            2.419160e-01
# reviews_per_month              3.425438e+00
# dtype: float64

# %%
#Lower Quartile / First Quartile
df.quantile(0.25, numeric_only=True)
# Out:
# id                             2.121091e+07
# host_id                        1.764159e+07
# latitude                       4.068828e+01
# longitude                     -7.398326e+01
# accommodates                   2.000000e+00
# bathrooms                      1.000000e+00
# bedrooms                       1.000000e+00
# beds                           1.000000e+00
# minimum_nights                 3.000000e+01
# maximum_nights                 1.200000e+02
# minimum_minimum_nights         3.000000e+01
# maximum_minimum_nights         3.000000e+01
# minimum_maximum_nights         3.600000e+02
# maximum_maximum_nights         3.650000e+02
# minimum_nights_avg_ntm         3.000000e+01
# maximum_nights_avg_ntm         3.650000e+02
# availability_30                0.000000e+00
# availability_60                0.000000e+00
# availability_90                0.000000e+00
# availability_365               0.000000e+00
# number_of_reviews              0.000000e+00
# number_of_reviews_ltm          0.000000e+00
# number_of_reviews_l30d         0.000000e+00
# availability_eoy               0.000000e+00
# number_of_reviews_ly           0.000000e+00
# estimated_occupancy_l365d      0.000000e+00
# estimated_revenue_l365d        0.000000e+00
# review_scores_rating           4.650000e+00
# review_scores_accuracy         4.710000e+00
# review_scores_cleanliness      4.540000e+00
# review_scores_checkin          4.820000e+00
# review_scores_communication    4.820000e+00
# review_scores_location         4.650000e+00
# review_scores_value            4.530000e+00
# reviews_per_month              8.000000e-02
# Name: 0.25, dtype: float64

# %%
#Second Quartile / Median
df.quantile(0.50, numeric_only=True)
# Out:
# id                             5.004978e+07
# host_id                        8.336440e+07
# latitude                       4.072594e+01
# longitude                     -7.395471e+01
# accommodates                   2.000000e+00
# bathrooms                      1.000000e+00
# bedrooms                       1.000000e+00
# beds                           1.000000e+00
# minimum_nights                 3.000000e+01
# maximum_nights                 3.650000e+02
# minimum_minimum_nights         3.000000e+01
# maximum_minimum_nights         3.000000e+01
# minimum_maximum_nights         3.650000e+02
# maximum_maximum_nights         7.300000e+02
# minimum_nights_avg_ntm         3.000000e+01
# maximum_nights_avg_ntm         5.791000e+02
# availability_30                0.000000e+00
# availability_60                7.000000e+00
# availability_90                2.600000e+01
# availability_365               1.530000e+02
# number_of_reviews              3.000000e+00
# number_of_reviews_ltm          0.000000e+00
# number_of_reviews_l30d         0.000000e+00
# availability_eoy               8.500000e+01
# number_of_reviews_ly           0.000000e+00
# estimated_occupancy_l365d      0.000000e+00
# estimated_revenue_l365d        0.000000e+00
# review_scores_rating           4.860000e+00
# review_scores_accuracy         4.900000e+00
# review_scores_cleanliness      4.810000e+00
# review_scores_checkin          4.950000e+00
# review_scores_communication    4.960000e+00
# review_scores_location         4.850000e+00
# review_scores_value            4.760000e+00
# reviews_per_month              2.600000e-01
# Name: 0.5, dtype: float64

# %%
#IQR (Interquartile Range)
df.quantile(0.75, numeric_only=True) - df.quantile(0.25, numeric_only=True)
# Out:
# id                             9.277467e+17
# host_id                        2.859807e+08
# latitude                       7.406750e-02
# longitude                      5.540750e-02
# accommodates                   2.000000e+00
# bathrooms                      0.000000e+00
# bedrooms                       1.000000e+00
# beds                           1.000000e+00
# minimum_nights                 0.000000e+00
# maximum_nights                 1.005000e+03
# minimum_minimum_nights         0.000000e+00
# maximum_minimum_nights         0.000000e+00
# minimum_maximum_nights         7.650000e+02
# maximum_maximum_nights         7.600000e+02
# minimum_nights_avg_ntm         0.000000e+00
# maximum_nights_avg_ntm         7.600000e+02
# availability_30                1.800000e+01
# availability_60                4.600000e+01
# availability_90                7.500000e+01
# availability_365               3.100000e+02
# number_of_reviews              2.300000e+01
# number_of_reviews_ltm          1.000000e+00
# number_of_reviews_l30d         0.000000e+00
# availability_eoy               1.690000e+02
# number_of_reviews_ly           1.000000e+00
# estimated_occupancy_l365d      6.000000e+01
# estimated_revenue_l365d        1.851000e+04
# review_scores_rating           3.500000e-01
# review_scores_accuracy         2.900000e-01
# review_scores_cleanliness      4.600000e-01
# review_scores_checkin          1.800000e-01
# review_scores_communication    1.800000e-01
# review_scores_location         3.500000e-01
# review_scores_value            4.100000e-01
# reviews_per_month              8.600000e-01
# dtype: float64

# %%
# Generate Descriptive statistic

df.describe(include=['int64', 'float64'])
# Out:
#                  id       host_id      latitude     longitude  accommodates  \
# count  3.632200e+04  3.632200e+04  36322.000000  36322.000000  36322.000000
# mean   4.382216e+17  1.713590e+08     40.728557    -73.946974      2.751886
# std    5.199100e+17  1.893709e+08      0.056482      0.055252      1.891702
# min    2.539000e+03  1.678000e+03     40.500366    -74.251907      1.000000
# 25%    2.121091e+07  1.764159e+07     40.688282    -73.983260      2.000000
# 50%    5.004978e+07  8.336440e+07     40.725941    -73.954711      2.000000
# 75%    9.277467e+17  3.036223e+08     40.762350    -73.927853      4.000000
# max    1.444534e+18  7.005911e+08     40.911390    -73.711822     16.000000
#
#           bathrooms      bedrooms          beds  minimum_nights  \
# count  21682.000000  30274.000000  21620.000000    36322.000000
# mean       1.188382      1.383332      1.636494       29.205716
# std        0.554439      0.938192      1.193949       35.111004
# min        0.000000      0.000000      0.000000        1.000000
# 25%        1.000000      1.000000      1.000000       30.000000
# 50%        1.000000      1.000000      1.000000       30.000000
# 75%        1.000000      2.000000      2.000000       30.000000
# max       15.500000     15.000000     40.000000     1124.000000
#
#        maximum_nights  ...  estimated_occupancy_l365d  \
# count    3.632200e+04  ...               36322.000000
# mean     6.024392e+04  ...                  47.845466
# std      1.126843e+07  ...                  85.466550
# min      1.000000e+00  ...                   0.000000
# 25%      1.200000e+02  ...                   0.000000
# 50%      3.650000e+02  ...                   0.000000
# 75%      1.125000e+03  ...                  60.000000
# max      2.147484e+09  ...                 255.000000
#
#        estimated_revenue_l365d  review_scores_rating  review_scores_accuracy  \
# count             2.145900e+04          25171.000000            25161.000000
# mean              1.523824e+04              4.725706                4.765266
# std               9.763701e+04              0.450831                0.437723
# min               0.000000e+00              0.000000                0.000000
# 25%               0.000000e+00              4.650000                4.710000
# 50%               0.000000e+00              4.860000                4.900000
# 75%               1.851000e+04              5.000000                5.000000
# max               1.275000e+07              5.000000                5.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count               25170.000000           25157.000000
# mean                    4.658376               4.835495
# std                     0.499909               0.375887
# min                     0.000000               0.000000
# 25%                     4.540000               4.820000
# 50%                     4.810000               4.950000
# 75%                     5.000000               5.000000
# max                     5.000000               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                 25165.000000            25154.000000
# mean                      4.824200                4.744684
# std                       0.415509                0.389568
# min                       0.000000                0.000000
# 25%                       4.820000                4.650000
# 50%                       4.960000                4.850000
# 75%                       5.000000                5.000000
# max                       5.000000                5.000000
#
#        review_scores_value  reviews_per_month
# count         25155.000000       25171.000000
# mean              4.640968           0.817262
# std               0.491850           1.850794
# min               0.000000           0.010000
# 25%               4.530000           0.080000
# 50%               4.760000           0.260000
# 75%               4.940000           0.940000
# max               5.000000         121.970000
#
# [8 rows x 35 columns]

# %%
df.describe(include=['object', 'category'])
# Out:
#                                   name  host_since host_location  \
# count                            36320       36307         28913
# unique                           34732        5159           985
# top     Water View King Bed Hotel Room  2016-12-16  New York, NY
# freq                                30        1060         21784
#
#        host_acceptance_rate  host_neighbourhood  host_verifications  \
# count                 21720               29034               36307
# unique                  100                 535                   7
# top                    100%  Bedford-Stuyvesant  ['email', 'phone']
# freq                   5681                1900               28107
#
#        host_identity_verified neighbourhood_cleansed  \
# count                   36307                  36322
# unique                      2                    223
# top                         t     Bedford-Stuyvesant
# freq                    31711                   2615
#
#        neighbourhood_group_cleansed       property_type        room_type  \
# count                         36322               36322            36322
# unique                            5                  74                4
# top                       Manhattan  Entire rental unit  Entire home/apt
# freq                          16081               15335            19435
#
#        bathrooms_text                                          amenities  \
# count           36286                                              36322
# unique             33                                              29619
# top            1 bath  ["Washer", "Kitchen", "Smoke alarm", "TV", "Wi...
# freq            18449                                                225
#
#           price has_availability first_review last_review license  \
# count     21459            30705        25171       25171    5329
# unique     1101                1         4416        3322    1963
# top     $150.00                t   2023-01-01  2025-05-31  Exempt
# freq        318            30705           61         410    3052
#
#        instant_bookable
# count             36322
# unique                2
# top                   f
# freq              29114

# %%
# Return unbiased kurtosis using Fisher’s definition of kurtosis

df.kurt(numeric_only=True)
# Out:
# id                                -1.401959
# host_id                           -0.445927
# latitude                           0.185334
# longitude                          3.512597
# accommodates                      11.440393
# bathrooms                         39.188595
# bedrooms                           9.363229
# beds                              63.524275
# minimum_nights                   327.625721
# maximum_nights                 36315.699937
# minimum_minimum_nights           332.669980
# maximum_minimum_nights            65.499335
# minimum_maximum_nights          7260.147714
# maximum_maximum_nights          2416.771930
# minimum_nights_avg_ntm           270.452002
# maximum_nights_avg_ntm          3818.781157
# availability_30                   -0.948818
# availability_60                   -1.322379
# availability_90                   -1.487277
# availability_365                  -1.645887
# number_of_reviews                299.986529
# number_of_reviews_ltm           2540.283167
# number_of_reviews_l30d          3514.517722
# availability_eoy                  -1.662418
# number_of_reviews_ly            2765.659814
# estimated_occupancy_l365d          1.002483
# estimated_revenue_l365d        13596.739717
# review_scores_rating              28.882435
# review_scores_accuracy            33.607508
# review_scores_cleanliness         18.043900
# review_scores_checkin             52.271258
# review_scores_communication       42.569261
# review_scores_location            32.160635
# review_scores_value               20.395742
# reviews_per_month                921.506586
# dtype: float64

# %%
#Correlation

df.corr(numeric_only=True)
# Out:
#                                    id   host_id  latitude  longitude  \
# id                           1.000000  0.492229  0.004636   0.022908
# host_id                      0.492229  1.000000  0.010077   0.095087
# latitude                     0.004636  0.010077  1.000000   0.045285
# longitude                    0.022908  0.095087  0.045285   1.000000
# accommodates                 0.046608  0.070933 -0.022850  -0.015163
# bathrooms                    0.026864 -0.040499 -0.050435   0.006081
# bedrooms                     0.063066 -0.005971 -0.081804   0.058903
# beds                        -0.059784  0.001589 -0.073136   0.040102
# minimum_nights              -0.075441 -0.090809  0.020132   0.009704
# maximum_nights              -0.004475 -0.004280  0.005820  -0.002986
# minimum_minimum_nights      -0.079508 -0.095362  0.017004   0.012911
# maximum_minimum_nights       0.056142 -0.098046  0.034993  -0.077607
# minimum_maximum_nights      -0.009915  0.002812  0.006350  -0.006094
# maximum_maximum_nights      -0.017147  0.008484  0.008432  -0.011814
# minimum_nights_avg_ntm      -0.066699 -0.101055  0.008716   0.006057
# maximum_nights_avg_ntm      -0.015264  0.006623  0.007923  -0.010450
# availability_30              0.270669  0.261450 -0.059587   0.145635
# availability_60              0.315316  0.285520 -0.059777   0.137928
# availability_90              0.354170  0.298781 -0.053372   0.123580
# availability_365             0.395848  0.258651 -0.027138   0.084152
# number_of_reviews           -0.189646 -0.052308 -0.051667   0.038852
# number_of_reviews_ltm        0.074114  0.114889 -0.030416   0.008805
# number_of_reviews_l30d       0.090891  0.117485 -0.035910   0.034069
# availability_eoy             0.395149  0.296153 -0.045903   0.104370
# number_of_reviews_ly         0.049823  0.094635 -0.028200   0.012096
# estimated_occupancy_l365d    0.093672  0.108443 -0.045009   0.037709
# estimated_revenue_l365d      0.000888  0.032053 -0.000218  -0.032271
# review_scores_rating        -0.047575 -0.110851 -0.056247   0.006239
# review_scores_accuracy      -0.082091 -0.127672 -0.049366   0.006845
# review_scores_cleanliness    0.013949 -0.022907 -0.055399   0.026748
# review_scores_checkin       -0.057521 -0.104216 -0.046294   0.012519
# review_scores_communication -0.077099 -0.125427 -0.047989   0.018134
# review_scores_location      -0.062596 -0.093023  0.008788  -0.139620
# review_scores_value         -0.104843 -0.130992 -0.065305   0.035187
# reviews_per_month            0.193122  0.226661 -0.044892   0.033689
#
#                              accommodates  bathrooms  bedrooms      beds  \
# id                               0.046608   0.026864  0.063066 -0.059784
# host_id                          0.070933  -0.040499 -0.005971  0.001589
# latitude                        -0.022850  -0.050435 -0.081804 -0.073136
# longitude                       -0.015163   0.006081  0.058903  0.040102
# accommodates                     1.000000   0.387999  0.521601  0.718017
# bathrooms                        0.387999   1.000000  0.450212  0.406261
# bedrooms                         0.521601   0.450212  1.000000  0.601655
# beds                             0.718017   0.406261  0.601655  1.000000
# minimum_nights                  -0.037622   0.068319  0.010848 -0.029285
# maximum_nights                  -0.004852   0.023120  0.003750  0.018829
# minimum_minimum_nights          -0.039827   0.069366  0.012229 -0.029306
# maximum_minimum_nights          -0.033651   0.043285 -0.017679 -0.059307
# minimum_maximum_nights          -0.000939  -0.002308 -0.004679 -0.003625
# maximum_maximum_nights          -0.004495  -0.006924 -0.008779 -0.008980
# minimum_nights_avg_ntm          -0.046219   0.074244  0.009003 -0.033860
# maximum_nights_avg_ntm          -0.003007  -0.005912 -0.007762 -0.007431
# availability_30                  0.048860   0.038504  0.018149  0.009519
# availability_60                  0.050464   0.036987  0.003031 -0.004956
# availability_90                  0.059208   0.029065  0.001842 -0.005125
# availability_365                 0.094866   0.059671  0.014074  0.029577
# number_of_reviews                0.025814  -0.047690 -0.052107  0.049467
# number_of_reviews_ltm            0.019743  -0.025178 -0.038189  0.009835
# number_of_reviews_l30d           0.023570  -0.020668 -0.024301  0.014546
# availability_eoy                 0.079960   0.027535  0.009856  0.012450
# number_of_reviews_ly             0.016196  -0.024332 -0.038484  0.008151
# estimated_occupancy_l365d        0.032000  -0.050435 -0.086477  0.034491
# estimated_revenue_l365d          0.070866   0.032477  0.031678  0.067606
# review_scores_rating             0.008123   0.014156  0.025610  0.028755
# review_scores_accuracy          -0.001000   0.001768  0.010823  0.024909
# review_scores_cleanliness        0.037964   0.004660  0.018678  0.035565
# review_scores_checkin           -0.004674   0.006469  0.005438  0.023956
# review_scores_communication      0.011286   0.004166  0.021052  0.040121
# review_scores_location          -0.004733  -0.006399 -0.032959 -0.008196
# review_scores_value             -0.006356   0.015417  0.037511  0.033159
# reviews_per_month                0.043649  -0.036402 -0.025621  0.014996
#
#                              minimum_nights  maximum_nights  ...  \
# id                                -0.075441       -0.004475  ...
# host_id                           -0.090809       -0.004280  ...
# latitude                           0.020132        0.005820  ...
# longitude                          0.009704       -0.002986  ...
# accommodates                      -0.037622       -0.004852  ...
# bathrooms                          0.068319        0.023120  ...
# bedrooms                           0.010848        0.003750  ...
# beds                              -0.029285        0.018829  ...
# minimum_nights                     1.000000        0.000123  ...
# maximum_nights                     0.000123        1.000000  ...
# minimum_minimum_nights             0.989160        0.000148  ...
# maximum_minimum_nights             0.546532       -0.000684  ...
# minimum_maximum_nights            -0.001671        0.447204  ...
# maximum_maximum_nights            -0.009613        0.258159  ...
# minimum_nights_avg_ntm             0.929094        0.000003  ...
# maximum_nights_avg_ntm            -0.006399        0.368735  ...
# availability_30                    0.006434       -0.003923  ...
# availability_60                   -0.004756       -0.004571  ...
# availability_90                   -0.005263       -0.005164  ...
# availability_365                   0.006525       -0.005795  ...
# number_of_reviews                 -0.094110       -0.001879  ...
# number_of_reviews_ltm             -0.134551       -0.001064  ...
# number_of_reviews_l30d            -0.138239       -0.001087  ...
# availability_eoy                  -0.002361       -0.005718  ...
# number_of_reviews_ly              -0.127210       -0.001019  ...
# estimated_occupancy_l365d         -0.164560       -0.002974  ...
# estimated_revenue_l365d           -0.061989       -0.004991  ...
# review_scores_rating               0.002267       -0.014725  ...
# review_scores_accuracy             0.009375       -0.015743  ...
# review_scores_cleanliness         -0.039472       -0.012424  ...
# review_scores_checkin              0.011401       -0.019680  ...
# review_scores_communication        0.006229       -0.017486  ...
# review_scores_location             0.008060       -0.006673  ...
# review_scores_value                0.014780       -0.012404  ...
# reviews_per_month                 -0.157204       -0.002745  ...
#
#                              estimated_occupancy_l365d  \
# id                                            0.093672
# host_id                                       0.108443
# latitude                                     -0.045009
# longitude                                     0.037709
# accommodates                                  0.032000
# bathrooms                                    -0.050435
# bedrooms                                     -0.086477
# beds                                          0.034491
# minimum_nights                               -0.164560
# maximum_nights                               -0.002974
# minimum_minimum_nights                       -0.172020
# maximum_minimum_nights                       -0.147239
# minimum_maximum_nights                        0.013598
# maximum_maximum_nights                        0.020244
# minimum_nights_avg_ntm                       -0.154507
# maximum_nights_avg_ntm                        0.021983
# availability_30                               0.003185
# availability_60                               0.054895
# availability_90                               0.093413
# availability_365                              0.180737
# number_of_reviews                             0.394202
# number_of_reviews_ltm                         0.443654
# number_of_reviews_l30d                        0.428764
# availability_eoy                              0.156304
# number_of_reviews_ly                          0.420292
# estimated_occupancy_l365d                     1.000000
# estimated_revenue_l365d                       0.208831
# review_scores_rating                          0.078473
# review_scores_accuracy                        0.055099
# review_scores_cleanliness                     0.118624
# review_scores_checkin                         0.056967
# review_scores_communication                   0.044643
# review_scores_location                        0.020332
# review_scores_value                           0.038024
# reviews_per_month                             0.426746
#
#                              estimated_revenue_l365d  review_scores_rating  \
# id                                          0.000888             -0.047575
# host_id                                     0.032053             -0.110851
# latitude                                   -0.000218             -0.056247
# longitude                                  -0.032271              0.006239
# accommodates                                0.070866              0.008123
# bathrooms                                   0.032477              0.014156
# bedrooms                                    0.031678              0.025610
# beds                                        0.067606              0.028755
# minimum_nights                             -0.061989              0.002267
# maximum_nights                             -0.004991             -0.014725
# minimum_minimum_nights                     -0.064447              0.004280
# maximum_minimum_nights                     -0.052380             -0.027442
# minimum_maximum_nights                      0.003569             -0.017734
# maximum_maximum_nights                      0.005776             -0.017810
# minimum_nights_avg_ntm                     -0.059398              0.001298
# maximum_nights_avg_ntm                      0.007326             -0.020718
# availability_30                            -0.034170             -0.078281
# availability_60                            -0.029369             -0.076531
# availability_90                            -0.031836             -0.073488
# availability_365                           -0.032345             -0.065263
# number_of_reviews                           0.077982              0.053021
# number_of_reviews_ltm                       0.126876              0.021089
# number_of_reviews_l30d                      0.102097              0.036147
# availability_eoy                           -0.031933             -0.070074
# number_of_reviews_ly                        0.100912              0.019079
# estimated_occupancy_l365d                   0.208831              0.078473
# estimated_revenue_l365d                     1.000000              0.023047
# review_scores_rating                        0.023047              1.000000
# review_scores_accuracy                      0.016236              0.794635
# review_scores_cleanliness                   0.033128              0.720604
# review_scores_checkin                       0.012133              0.659909
# review_scores_communication                 0.013682              0.745896
# review_scores_location                      0.029512              0.566246
# review_scores_value                         0.015364              0.810578
# reviews_per_month                           0.107890              0.037680
#
#                              review_scores_accuracy  \
# id                                        -0.082091
# host_id                                   -0.127672
# latitude                                  -0.049366
# longitude                                  0.006845
# accommodates                              -0.001000
# bathrooms                                  0.001768
# bedrooms                                   0.010823
# beds                                       0.024909
# minimum_nights                             0.009375
# maximum_nights                            -0.015743
# minimum_minimum_nights                     0.010959
# maximum_minimum_nights                    -0.015790
# minimum_maximum_nights                    -0.017741
# maximum_maximum_nights                    -0.018844
# minimum_nights_avg_ntm                     0.008294
# maximum_nights_avg_ntm                    -0.021390
# availability_30                           -0.094956
# availability_60                           -0.096614
# availability_90                           -0.096947
# availability_365                          -0.095862
# number_of_reviews                          0.060550
# number_of_reviews_ltm                      0.013488
# number_of_reviews_l30d                     0.028226
# availability_eoy                          -0.099187
# number_of_reviews_ly                       0.012245
# estimated_occupancy_l365d                  0.055099
# estimated_revenue_l365d                    0.016236
# review_scores_rating                       0.794635
# review_scores_accuracy                     1.000000
# review_scores_cleanliness                  0.672340
# review_scores_checkin                      0.660411
# review_scores_communication                0.706712
# review_scores_location                     0.538517
# review_scores_value                        0.767850
# reviews_per_month                          0.031407
#
#                              review_scores_cleanliness  review_scores_checkin  \
# id                                            0.013949              -0.057521
# host_id                                      -0.022907              -0.104216
# latitude                                     -0.055399              -0.046294
# longitude                                     0.026748               0.012519
# accommodates                                  0.037964              -0.004674
# bathrooms                                     0.004660               0.006469
# bedrooms                                      0.018678               0.005438
# beds                                          0.035565               0.023956
# minimum_nights                               -0.039472               0.011401
# maximum_nights                               -0.012424              -0.019680
# minimum_minimum_nights                       -0.039740               0.014273
# maximum_minimum_nights                       -0.040520              -0.015647
# minimum_maximum_nights                       -0.006197              -0.013918
# maximum_maximum_nights                       -0.005757              -0.017772
# minimum_nights_avg_ntm                       -0.038562               0.010089
# maximum_nights_avg_ntm                       -0.007499              -0.015594
# availability_30                              -0.012041              -0.083152
# availability_60                              -0.002806              -0.081530
# availability_90                               0.003344              -0.077967
# availability_365                              0.011347              -0.065243
# number_of_reviews                             0.091290               0.053445
# number_of_reviews_ltm                         0.047713               0.014333
# number_of_reviews_l30d                        0.058626               0.025590
# availability_eoy                              0.009315              -0.072060
# number_of_reviews_ly                          0.044933               0.013139
# estimated_occupancy_l365d                     0.118624               0.056967
# estimated_revenue_l365d                       0.033128               0.012133
# review_scores_rating                          0.720604               0.659909
# review_scores_accuracy                        0.672340               0.660411
# review_scores_cleanliness                     1.000000               0.546144
# review_scores_checkin                         0.546144               1.000000
# review_scores_communication                   0.551392               0.681997
# review_scores_location                        0.454984               0.502235
# review_scores_value                           0.652864               0.612616
# reviews_per_month                             0.080389               0.028021
#
#                              review_scores_communication  \
# id                                             -0.077099
# host_id                                        -0.125427
# latitude                                       -0.047989
# longitude                                       0.018134
# accommodates                                    0.011286
# bathrooms                                       0.004166
# bedrooms                                        0.021052
# beds                                            0.040121
# minimum_nights                                  0.006229
# maximum_nights                                 -0.017486
# minimum_minimum_nights                          0.008873
# maximum_minimum_nights                         -0.043733
# minimum_maximum_nights                         -0.022998
# maximum_maximum_nights                         -0.029180
# minimum_nights_avg_ntm                          0.002653
# maximum_nights_avg_ntm                         -0.030877
# availability_30                                -0.091137
# availability_60                                -0.096588
# availability_90                                -0.099783
# availability_365                               -0.097642
# number_of_reviews                               0.056102
# number_of_reviews_ltm                           0.014025
# number_of_reviews_l30d                          0.026692
# availability_eoy                               -0.099294
# number_of_reviews_ly                            0.012291
# estimated_occupancy_l365d                       0.044643
# estimated_revenue_l365d                         0.013682
# review_scores_rating                            0.745896
# review_scores_accuracy                          0.706712
# review_scores_cleanliness                       0.551392
# review_scores_checkin                           0.681997
# review_scores_communication                     1.000000
# review_scores_location                          0.511119
# review_scores_value                             0.699049
# reviews_per_month                               0.030789
#
#                              review_scores_location  review_scores_value  \
# id                                        -0.062596            -0.104843
# host_id                                   -0.093023            -0.130992
# latitude                                   0.008788            -0.065305
# longitude                                 -0.139620             0.035187
# accommodates                              -0.004733            -0.006356
# bathrooms                                 -0.006399             0.015417
# bedrooms                                  -0.032959             0.037511
# beds                                      -0.008196             0.033159
# minimum_nights                             0.008060             0.014780
# maximum_nights                            -0.006673            -0.012404
# minimum_minimum_nights                     0.010762             0.017052
# maximum_minimum_nights                    -0.010868            -0.044534
# minimum_maximum_nights                    -0.005871            -0.015374
# maximum_maximum_nights                    -0.000308            -0.022793
# minimum_nights_avg_ntm                     0.002327             0.008648
# maximum_nights_avg_ntm                    -0.003327            -0.021029
# availability_30                           -0.099868            -0.098426
# availability_60                           -0.098387            -0.109959
# availability_90                           -0.095431            -0.120146
# availability_365                          -0.089865            -0.134734
# number_of_reviews                          0.014674             0.075320
# number_of_reviews_ltm                      0.010163             0.014075
# number_of_reviews_l30d                     0.014494             0.031141
# availability_eoy                          -0.094439            -0.134222
# number_of_reviews_ly                       0.007339             0.011795
# estimated_occupancy_l365d                  0.020332             0.038024
# estimated_revenue_l365d                    0.029512             0.015364
# review_scores_rating                       0.566246             0.810578
# review_scores_accuracy                     0.538517             0.767850
# review_scores_cleanliness                  0.454984             0.652864
# review_scores_checkin                      0.502235             0.612616
# review_scores_communication                0.511119             0.699049
# review_scores_location                     1.000000             0.560457
# review_scores_value                        0.560457             1.000000
# reviews_per_month                          0.012259             0.040474
#
#                              reviews_per_month
# id                                    0.193122
# host_id                               0.226661
# latitude                             -0.044892
# longitude                             0.033689
# accommodates                          0.043649
# bathrooms                            -0.036402
# bedrooms                             -0.025621
# beds                                  0.014996
# minimum_nights                       -0.157204
# maximum_nights                       -0.002745
# minimum_minimum_nights               -0.160625
# maximum_minimum_nights               -0.120379
# minimum_maximum_nights                0.001318
# maximum_maximum_nights                0.007443
# minimum_nights_avg_ntm               -0.149302
# maximum_nights_avg_ntm                0.006531
# availability_30                       0.149719
# availability_60                       0.167434
# availability_90                       0.169340
# availability_365                      0.150331
# number_of_reviews                     0.721298
# number_of_reviews_ltm                 0.887701
# number_of_reviews_l30d                0.794993
# availability_eoy                      0.169082
# number_of_reviews_ly                  0.858458
# estimated_occupancy_l365d             0.426746
# estimated_revenue_l365d               0.107890
# review_scores_rating                  0.037680
# review_scores_accuracy                0.031407
# review_scores_cleanliness             0.080389
# review_scores_checkin                 0.028021
# review_scores_communication           0.030789
# review_scores_location                0.012259
# review_scores_value                   0.040474
# reviews_per_month                     1.000000
#
# [35 rows x 35 columns]

# %%
#Covariance

df.cov(numeric_only=True)
# Out:
#                                        id       host_id      latitude  \
# id                           2.703064e+35  4.846281e+25  1.361335e+14
# host_id                      4.846281e+25  3.586133e+16  1.077868e+05
# latitude                     1.361335e+14  1.077868e+05  3.190243e-03
# longitude                    6.580411e+14  9.948988e+05  1.413210e-04
# accommodates                 4.583931e+16  2.541072e+07 -2.441444e-03
# bathrooms                    7.898539e+15 -4.566606e+06 -1.649088e-03
# bedrooms                     3.129746e+16 -1.099891e+06 -4.362944e-03
# beds                        -3.783706e+16  3.854353e+05 -5.155419e-03
# minimum_nights              -1.377147e+18 -6.037865e+08  3.992476e-02
# maximum_nights              -2.621856e+22 -9.132490e+12  3.704370e+03
# minimum_minimum_nights      -1.445209e+18 -6.313670e+08  3.357713e-02
# maximum_minimum_nights       1.886925e+18 -1.200279e+09  1.277708e-01
# minimum_maximum_nights      -1.298764e+23  1.341608e+13  9.036565e+03
# maximum_maximum_nights      -3.889660e+23  7.010137e+13  2.078062e+04
# minimum_nights_avg_ntm      -1.303038e+18 -7.190870e+08  1.849968e-02
# maximum_nights_avg_ntm      -2.424555e+23  3.831773e+13  1.367335e+04
# availability_30              1.660960e+18  5.843781e+08 -3.972435e-02
# availability_60              3.945175e+18  1.301193e+09 -8.125298e-02
# availability_90              6.641748e+18  2.040842e+09 -1.087351e-01
# availability_365             2.995188e+19  7.128454e+09 -2.230751e-01
# number_of_reviews           -6.643805e+18 -6.674642e+08 -1.966381e-01
# number_of_reviews_ltm        7.737971e+17  4.369057e+08 -3.449981e-02
# number_of_reviews_l30d       7.008887e+16  3.299837e+07 -3.008337e-03
# availability_eoy             1.647971e+19  4.498728e+09 -2.079771e-01
# number_of_reviews_ly         4.951536e+17  3.425673e+08 -3.044693e-02
# estimated_occupancy_l365d    4.162312e+18  1.755131e+09 -2.172718e-01
# estimated_revenue_l365d      4.595908e+19  6.316030e+11 -1.262967e+00
# review_scores_rating        -9.733373e+15 -8.858254e+06 -1.461402e-03
# review_scores_accuracy      -1.630831e+16 -9.906495e+06 -1.245229e-03
# review_scores_cleanliness    3.164534e+15 -2.029787e+06 -1.596075e-03
# review_scores_checkin       -9.813306e+15 -6.944418e+06 -1.002829e-03
# review_scores_communication -1.453862e+16 -9.238177e+06 -1.149066e-03
# review_scores_location      -1.106811e+16 -6.424413e+06  1.973248e-04
# review_scores_value         -2.340511e+16 -1.142182e+07 -1.851105e-03
# reviews_per_month            1.622034e+17  7.435829e+07 -4.788263e-03
#
#                                 longitude  accommodates     bathrooms  \
# id                           6.580411e+14  4.583931e+16  7.898539e+15
# host_id                      9.948988e+05  2.541072e+07 -4.566606e+06
# latitude                     1.413210e-04 -2.441444e-03 -1.649088e-03
# longitude                    3.052732e-03 -1.584807e-03  2.034094e-04
# accommodates                -1.584807e-03  3.578536e+00  4.381669e-01
# bathrooms                    2.034094e-04  4.381669e-01  3.074030e-01
# bedrooms                     3.105239e-03  9.712449e-01  2.407892e-01
# beds                         2.891676e-03  1.746509e+00  2.692053e-01
# minimum_nights               1.882444e-02 -2.498832e+00  1.275265e+00
# maximum_nights              -1.858987e+03 -1.034333e+05  5.075286e+00
# minimum_minimum_nights       2.494079e-02 -2.634042e+00  1.283480e+00
# maximum_minimum_nights      -2.771944e-01 -4.115233e+00  1.804047e+00
# minimum_maximum_nights      -8.483432e+03 -4.476710e+04 -1.865966e+04
# maximum_maximum_nights      -2.848049e+04 -3.710502e+05 -1.679319e+05
# minimum_nights_avg_ntm       1.257479e-02 -3.285397e+00  1.505592e+00
# maximum_nights_avg_ntm      -1.764004e+04 -1.737797e+05 -7.949400e+04
# availability_30              9.497341e-02  1.090934e+00  2.625429e-01
# availability_60              1.833952e-01  2.297324e+00  4.761291e-01
# availability_90              2.462838e-01  4.039958e+00  5.088106e-01
# availability_365             6.766726e-01  2.611743e+01  3.563722e+00
# number_of_reviews            1.446447e-01  3.290426e+00 -2.135926e+00
# number_of_reviews_ltm        9.769680e-03  7.499950e-01 -3.494754e-01
# number_of_reviews_l30d       2.791879e-03  6.613231e-02 -2.136984e-02
# availability_eoy             4.625716e-01  1.213357e+01  9.325999e-01
# number_of_reviews_ly         1.277486e-02  5.856379e-01 -3.236257e-01
# estimated_occupancy_l365d    1.780698e-01  5.173683e+00 -2.715905e+00
# estimated_revenue_l365d     -1.905349e+02  1.415157e+04  1.766194e+03
# review_scores_rating         1.606031e-04  6.755472e-03  3.256606e-03
# review_scores_accuracy       1.711134e-04 -8.071784e-04  3.898866e-04
# review_scores_cleanliness    7.635667e-04  3.500885e-02  1.084081e-03
# review_scores_checkin        2.687725e-04 -3.241578e-03  1.207001e-03
# review_scores_communication  4.302885e-04  8.650652e-03  9.031423e-04
# review_scores_location      -3.106746e-03 -3.402025e-03 -1.238924e-03
# review_scores_value          9.885126e-04 -5.768237e-03  3.906460e-03
# reviews_per_month            3.560460e-03  1.490209e-01 -4.126124e-02
#
#                                  bedrooms          beds  minimum_nights  \
# id                           3.129746e+16 -3.783706e+16   -1.377147e+18
# host_id                     -1.099891e+06  3.854353e+05   -6.037865e+08
# latitude                    -4.362944e-03 -5.155419e-03    3.992476e-02
# longitude                    3.105239e-03  2.891676e-03    1.882444e-02
# accommodates                 9.712449e-01  1.746509e+00   -2.498832e+00
# bathrooms                    2.407892e-01  2.692053e-01    1.275265e+00
# bedrooms                     8.802045e-01  6.943029e-01    3.368126e-01
# beds                         6.943029e-01  1.425515e+00   -1.178163e+00
# minimum_nights               3.368126e-01 -1.178163e+00    1.232783e+03
# maximum_nights               4.044441e+02  8.899704e+00    4.852524e+04
# minimum_minimum_nights       3.774779e-01 -1.168666e+00    1.214232e+03
# maximum_minimum_nights      -1.101737e+00 -5.329228e+00    1.240503e+03
# minimum_maximum_nights      -1.083671e+05 -6.320583e+04   -1.478074e+06
# maximum_maximum_nights      -3.802951e+05 -4.696698e+05   -1.472612e+07
# minimum_nights_avg_ntm       2.983500e-01 -1.480006e+00    1.225782e+03
# maximum_nights_avg_ntm      -2.265264e+05 -2.154521e+05   -6.864485e+06
# availability_30              2.066072e-01  1.397681e-01    2.666443e+00
# availability_60              6.918701e-02 -1.373671e-01   -4.018829e+00
# availability_90              6.184129e-02 -1.931980e-01   -6.665439e+00
# availability_365             1.859028e+00  3.801616e+00    3.334102e+01
# number_of_reviews           -3.493163e+00  4.776718e+00   -2.226512e+02
# number_of_reviews_ltm       -7.703513e-01  2.943276e-01   -9.486941e+01
# number_of_reviews_l30d      -3.677055e-02  3.243009e-02   -7.198984e+00
# availability_eoy             7.200569e-01  9.078578e-01   -6.650275e+00
# number_of_reviews_ly        -7.439933e-01  2.337563e-01   -8.537816e+01
# estimated_occupancy_l365d   -7.288624e+00  4.001864e+00   -4.938142e+02
# estimated_revenue_l365d      3.001718e+03  7.917915e+03   -2.042221e+05
# review_scores_rating         1.019067e-02  1.617400e-02    3.568383e-02
# review_scores_accuracy       4.166150e-03  1.343845e-02    1.432977e-01
# review_scores_cleanliness    7.945681e-03  2.023017e-02   -6.889471e-01
# review_scores_checkin        1.788457e-03  1.093360e-02    1.496653e-01
# review_scores_communication  7.765282e-03  2.127151e-02    9.036894e-02
# review_scores_location      -1.108531e-02 -3.880077e-03    1.096575e-01
# review_scores_value          1.631961e-02  2.055539e-02    2.538885e-01
# reviews_per_month           -4.420041e-02  4.166542e-02   -1.015828e+01
#
#                              maximum_nights  ...  estimated_occupancy_l365d  \
# id                            -2.621856e+22  ...               4.162312e+18
# host_id                       -9.132490e+12  ...               1.755131e+09
# latitude                       3.704370e+03  ...              -2.172718e-01
# longitude                     -1.858987e+03  ...               1.780698e-01
# accommodates                  -1.034333e+05  ...               5.173683e+00
# bathrooms                      5.075286e+00  ...              -2.715905e+00
# bedrooms                       4.044441e+02  ...              -7.288624e+00
# beds                           8.899704e+00  ...               4.001864e+00
# minimum_nights                 4.852524e+04  ...              -4.938142e+02
# maximum_nights                 1.269776e+14  ...              -2.863896e+06
# minimum_minimum_nights         5.837999e+04  ...              -5.140054e+02
# maximum_minimum_nights        -4.980923e+05  ...              -8.135027e+02
# minimum_maximum_nights         1.269635e+14  ...               2.928090e+07
# maximum_maximum_nights         1.269285e+14  ...               7.549026e+07
# minimum_nights_avg_ntm         1.070177e+03  ...              -4.961972e+02
# maximum_nights_avg_ntm         1.269483e+14  ...               5.740149e+07
# availability_30               -5.218240e+05  ...               3.213021e+00
# availability_60               -1.239461e+06  ...               1.129064e+02
# availability_90               -2.098900e+06  ...               2.879699e+02
# availability_365              -9.504016e+06  ...               2.248081e+03
# number_of_reviews             -1.427020e+06  ...               2.270176e+03
# number_of_reviews_ltm         -2.406583e+05  ...               7.614426e+02
# number_of_reviews_l30d        -1.816436e+04  ...               5.435170e+01
# availability_eoy              -5.168859e+06  ...               1.071584e+03
# number_of_reviews_ly          -2.195323e+05  ...               6.866382e+02
# estimated_occupancy_l365d     -2.863896e+06  ...               7.304531e+03
# estimated_revenue_l365d       -1.935610e+05  ...               1.983464e+06
# review_scores_rating          -8.986211e+04  ...               3.370613e+00
# review_scores_accuracy        -9.330058e+04  ...               2.298037e+00
# review_scores_cleanliness     -8.407608e+04  ...               5.649922e+00
# review_scores_checkin         -1.001620e+05  ...               2.040402e+00
# review_scores_communication   -9.836132e+04  ...               1.767383e+00
# review_scores_location        -3.519896e+04  ...               7.547511e-01
# review_scores_value           -8.261146e+04  ...               1.782110e+00
# reviews_per_month             -6.878029e+04  ...               7.524942e+01
#
#                              estimated_revenue_l365d  review_scores_rating  \
# id                                      4.595908e+19         -9.733373e+15
# host_id                                 6.316030e+11         -8.858254e+06
# latitude                               -1.262967e+00         -1.461402e-03
# longitude                              -1.905349e+02          1.606031e-04
# accommodates                            1.415157e+04          6.755472e-03
# bathrooms                               1.766194e+03          3.256606e-03
# bedrooms                                3.001718e+03          1.019067e-02
# beds                                    7.917915e+03          1.617400e-02
# minimum_nights                         -2.042221e+05          3.568383e-02
# maximum_nights                         -1.935610e+05         -8.986211e+04
# minimum_minimum_nights                 -2.104175e+05          6.709948e-02
# maximum_minimum_nights                 -3.858724e+05         -6.119275e-01
# minimum_maximum_nights                  5.109022e+09         -2.419635e+05
# maximum_maximum_nights                  2.479733e+10         -3.917584e+05
# minimum_nights_avg_ntm                 -2.126091e+05          2.215902e-02
# maximum_nights_avg_ntm                  1.743512e+10         -3.358531e+05
# availability_30                        -4.109457e+04         -3.957234e-01
# availability_60                        -6.665419e+04         -7.953272e-01
# availability_90                        -9.819474e+04         -1.152357e+00
# availability_365                       -3.376738e+05         -4.155412e+00
# number_of_reviews                       6.162143e+05          1.865522e+00
# number_of_reviews_ltm                   3.110148e+05          2.273120e-01
# number_of_reviews_l30d                  1.864853e+04          2.876506e-02
# availability_eoy                       -1.900287e+05         -2.457551e+00
# number_of_reviews_ly                    2.371102e+05          1.958983e-01
# estimated_occupancy_l365d               1.983464e+06          3.370613e+00
# estimated_revenue_l365d                 9.532985e+09          1.203964e+03
# review_scores_rating                    1.203964e+03          2.032488e-01
# review_scores_accuracy                  8.138001e+02          1.567600e-01
# review_scores_cleanliness               1.758365e+03          1.624077e-01
# review_scores_checkin                   5.135763e+02          1.117924e-01
# review_scores_communication             6.714363e+02          1.397163e-01
# review_scores_location                  1.299721e+03          9.942030e-02
# review_scores_value                     8.838453e+02          1.796838e-01
# reviews_per_month                       2.789558e+04          3.143989e-02
#
#                              review_scores_accuracy  \
# id                                    -1.630831e+16
# host_id                               -9.906495e+06
# latitude                              -1.245229e-03
# longitude                              1.711134e-04
# accommodates                          -8.071784e-04
# bathrooms                              3.898866e-04
# bedrooms                               4.166150e-03
# beds                                   1.343845e-02
# minimum_nights                         1.432977e-01
# maximum_nights                        -9.330058e+04
# minimum_minimum_nights                 1.668455e-01
# maximum_minimum_nights                -3.419330e-01
# minimum_maximum_nights                -2.350709e+05
# maximum_maximum_nights                -4.025490e+05
# minimum_nights_avg_ntm                 1.374641e-01
# maximum_nights_avg_ntm                -3.367355e+05
# availability_30                       -4.661041e-01
# availability_60                       -9.749032e-01
# availability_90                       -1.476027e+00
# availability_365                      -5.926006e+00
# number_of_reviews                      2.068805e+00
# number_of_reviews_ltm                  1.411855e-01
# number_of_reviews_l30d                 2.181282e-02
# availability_eoy                      -3.377301e+00
# number_of_reviews_ly                   1.220895e-01
# estimated_occupancy_l365d              2.298037e+00
# estimated_revenue_l365d                8.138001e+02
# review_scores_rating                   1.567600e-01
# review_scores_accuracy                 1.916012e-01
# review_scores_cleanliness              1.468342e-01
# review_scores_checkin                  1.086664e-01
# review_scores_communication            1.285186e-01
# review_scores_location                 9.184078e-02
# review_scores_value                    1.653274e-01
# reviews_per_month                      2.544801e-02
#
#                              review_scores_cleanliness  review_scores_checkin  \
# id                                        3.164534e+15          -9.813306e+15
# host_id                                  -2.029787e+06          -6.944418e+06
# latitude                                 -1.596075e-03          -1.002829e-03
# longitude                                 7.635667e-04           2.687725e-04
# accommodates                              3.500885e-02          -3.241578e-03
# bathrooms                                 1.084081e-03           1.207001e-03
# bedrooms                                  7.945681e-03           1.788457e-03
# beds                                      2.023017e-02           1.093360e-02
# minimum_nights                           -6.889471e-01           1.496653e-01
# maximum_nights                           -8.407608e+04          -1.001620e+05
# minimum_minimum_nights                   -6.908486e-01           1.866129e-01
# maximum_minimum_nights                   -1.001947e+00          -2.909975e-01
# minimum_maximum_nights                   -9.375235e+04          -1.583754e+05
# maximum_maximum_nights                   -1.404263e+05          -3.260355e+05
# minimum_nights_avg_ntm                   -7.297900e-01           1.436067e-01
# maximum_nights_avg_ntm                   -1.348035e+05          -2.108302e+05
# availability_30                          -6.749362e-02          -3.505156e-01
# availability_60                          -3.233098e-02          -7.064898e-01
# availability_90                           5.814184e-02          -1.019371e+00
# availability_365                          8.011570e-01          -3.463394e+00
# number_of_reviews                         3.561701e+00           1.568176e+00
# number_of_reviews_ltm                     5.702698e-01           1.288450e-01
# number_of_reviews_l30d                    5.173359e-02           1.698344e-02
# availability_eoy                          3.622337e-01          -2.106996e+00
# number_of_reviews_ly                      5.115828e-01           1.125082e-01
# estimated_occupancy_l365d                 5.649922e+00           2.040402e+00
# estimated_revenue_l365d                   1.758365e+03           5.135763e+02
# review_scores_rating                      1.624077e-01           1.117924e-01
# review_scores_accuracy                    1.468342e-01           1.086664e-01
# review_scores_cleanliness                 2.499087e-01           1.024073e-01
# review_scores_checkin                     1.024073e-01           1.412910e-01
# review_scores_communication               1.144490e-01           1.065072e-01
# review_scores_location                    8.842176e-02           7.354952e-02
# review_scores_value                       1.601881e-01           1.132639e-01
# reviews_per_month                         7.437972e-02           1.949798e-02
#
#                              review_scores_communication  \
# id                                         -1.453862e+16
# host_id                                    -9.238177e+06
# latitude                                   -1.149066e-03
# longitude                                   4.302885e-04
# accommodates                                8.650652e-03
# bathrooms                                   9.031423e-04
# bedrooms                                    7.765282e-03
# beds                                        2.127151e-02
# minimum_nights                              9.036894e-02
# maximum_nights                             -9.836132e+04
# minimum_minimum_nights                      1.282238e-01
# maximum_minimum_nights                     -8.989117e-01
# minimum_maximum_nights                     -2.892420e+05
# maximum_maximum_nights                     -5.916562e+05
# minimum_nights_avg_ntm                      4.173126e-02
# maximum_nights_avg_ntm                     -4.613888e+05
# availability_30                            -4.246408e-01
# availability_60                            -9.251597e-01
# availability_90                            -1.442109e+00
# availability_365                           -5.729789e+00
# number_of_reviews                           1.819451e+00
# number_of_reviews_ltm                       1.393461e-01
# number_of_reviews_l30d                      1.957924e-02
# availability_eoy                           -3.209393e+00
# number_of_reviews_ly                        1.163229e-01
# estimated_occupancy_l365d                   1.767383e+00
# estimated_revenue_l365d                     6.714363e+02
# review_scores_rating                        1.397163e-01
# review_scores_accuracy                      1.285186e-01
# review_scores_cleanliness                   1.144490e-01
# review_scores_checkin                       1.065072e-01
# review_scores_communication                 1.726474e-01
# review_scores_location                      8.273279e-02
# review_scores_value                         1.428544e-01
# reviews_per_month                           2.367962e-02
#
#                              review_scores_location  review_scores_value  \
# id                                    -1.106811e+16        -2.340511e+16
# host_id                               -6.424413e+06        -1.142182e+07
# latitude                               1.973248e-04        -1.851105e-03
# longitude                             -3.106746e-03         9.885126e-04
# accommodates                          -3.402025e-03        -5.768237e-03
# bathrooms                             -1.238924e-03         3.906460e-03
# bedrooms                              -1.108531e-02         1.631961e-02
# beds                                  -3.880077e-03         2.055539e-02
# minimum_nights                         1.096575e-01         2.538885e-01
# maximum_nights                        -3.519896e+04        -8.261146e+04
# minimum_minimum_nights                 1.458365e-01         2.917404e-01
# maximum_minimum_nights                -2.094941e-01        -1.083771e+00
# minimum_maximum_nights                -6.924385e+04        -2.289216e+05
# maximum_maximum_nights                -5.850175e+03        -5.471771e+05
# minimum_nights_avg_ntm                 3.433202e-02         1.610643e-01
# maximum_nights_avg_ntm                -4.662010e+04        -3.720296e+05
# availability_30                       -4.363151e-01        -5.429092e-01
# availability_60                       -8.835996e-01        -1.246812e+00
# availability_90                       -1.293108e+00        -2.055454e+00
# availability_365                      -4.944142e+00        -9.358783e+00
# number_of_reviews                      4.462623e-01         2.891946e+00
# number_of_reviews_ltm                  9.468946e-02         1.655642e-01
# number_of_reviews_l30d                 9.970159e-03         2.704459e-02
# availability_eoy                      -2.861826e+00        -5.135325e+00
# number_of_reviews_ly                   6.513095e-02         1.321677e-01
# estimated_occupancy_l365d              7.547511e-01         1.782110e+00
# estimated_revenue_l365d                1.299721e+03         8.838453e+02
# review_scores_rating                   9.942030e-02         1.796838e-01
# review_scores_accuracy                 9.184078e-02         1.653274e-01
# review_scores_cleanliness              8.842176e-02         1.601881e-01
# review_scores_checkin                  7.354952e-02         1.132639e-01
# review_scores_communication            8.273279e-02         1.428544e-01
# review_scores_location                 1.517631e-01         1.073892e-01
# review_scores_value                    1.073892e-01         2.419160e-01
# reviews_per_month                      8.840952e-03         3.685306e-02
#
#                              reviews_per_month
# id                                1.622034e+17
# host_id                           7.435829e+07
# latitude                         -4.788263e-03
# longitude                         3.560460e-03
# accommodates                      1.490209e-01
# bathrooms                        -4.126124e-02
# bedrooms                         -4.420041e-02
# beds                              4.166542e-02
# minimum_nights                   -1.015828e+01
# maximum_nights                   -6.878029e+04
# minimum_minimum_nights           -1.033788e+01
# maximum_minimum_nights           -1.102002e+01
# minimum_maximum_nights            7.381458e+04
# maximum_maximum_nights            6.720957e+05
# minimum_nights_avg_ntm           -1.046067e+01
# maximum_nights_avg_ntm            4.346111e+05
# availability_30                   3.107102e+00
# availability_60                   7.143304e+00
# availability_90                   1.090112e+01
# availability_365                  3.929509e+01
# number_of_reviews                 1.041866e+02
# number_of_reviews_ltm             3.928021e+01
# number_of_reviews_l30d            2.597188e+00
# availability_eoy                  2.434360e+01
# number_of_reviews_ly              3.618514e+01
# estimated_occupancy_l365d         7.524942e+01
# estimated_revenue_l365d           2.789558e+04
# review_scores_rating              3.143989e-02
# review_scores_accuracy            2.544801e-02
# review_scores_cleanliness         7.437972e-02
# review_scores_checkin             1.949798e-02
# review_scores_communication       2.367962e-02
# review_scores_location            8.840952e-03
# review_scores_value               3.685306e-02
# reviews_per_month                 3.425438e+00
#
# [35 rows x 35 columns]

# %% [markdown]
# <a class="anchor" id="2.3"></a>
# <h3 style="background-color:#38ACEC;font-family:newtimeroman;font-size:180%;text-align:center;border-radius: 15px 50px;">2.3 Fehlende Werte und Duplikate</h3>
#
# [**Inhaltsverzeichnis**](#0.1)

# %%
# Anzahl unterschiedlicher Zeilen: 36322
# Keine Duplikate

df.drop_duplicates().shape[0]
# Out:
# 36322

# %%
# Datums-Typen bearbeiten
if "host_since" in df.columns:
    df["host_since"] = pd.to_datetime(df["host_since"], errors="coerce")

# %%
# Bool-Typen bearbeiten
def to_bool(x):
    if pd.isna(x):
        return pd.NA
    s = str(x).strip().lower()
    if s == "t" or x == True: return True
    if s == "f" or x == False:  return False
    return pd.NA

col_bool = ["host_identity_verified","instant_bookable","has_availability"]
    
for c in ["host_identity_verified", "instant_bookable","has_availability"]:
    if c in df.columns:
        df[c] = df[c].map(to_bool).astype("boolean")

# %%
# Investigate Room Type
df["room_type"].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Hotel room', 'Shared room'],
#       dtype=object)

# %% [markdown]
# ### Spalte "price" bereinigen und fehlende Werte ausfüllen
#
# **Fehlende Werte** 40.9%
#
# **Ziel:** Die Spalte **`price`** sauber in **Float** konvertieren, Ausreißer entfernen und fehlende Werte hierarchischer Median-basiert imputieren.
#
# **Vorgehen:**
#
# - **Preis säubern:** in **Float** umwandeln; Währungszeichen und Tausendertrennzeichen entfernen.
# - **Unplausible Werte:** `price <= 0` oder **sehr hoch** (z. B. > **99,5%-Quantil**) → `NaN`.
# - **Check vor Imputation:** Verteilungen/Kennzahlen **vor** dem Füllen prüfen.
# - **Imputation:** hierarchischer **Median**.
# - **Check nach Imputation:** Verteilungen/Kennzahlen **nach** dem Füllen prüfen.

# %%
print("Missing price before imputation:", df["price"].isna().sum())
# Out:
# Missing price before imputation: 14863

# %%
# Investigate "price" column

# df[df["price"].isna() == True].loc[24]
df["price"].loc[20:26]

def find_currency(df):
    currency = []
    for i in df["price"].unique():
        currency.append(str(i)[0])
    currency.remove('n')
    return set(currency)

find_currency(df)
# Out:
# {'$'}

# %%
# Preis säubern: object -> float
df["price"] = (df["price"].astype(str)
                 .str.replace(r"[^\d.\-]", "", regex=True)
                 .replace({"": np.nan}))
df["price"] = pd.to_numeric(df["price"], errors="coerce")

# %%
# Offensichtliche Fehler -> NaN

df.loc[df["price"] <= 0, "price"] = np.nan
upper_cap = df["price"].quantile(0.995)  # sehr extreme Spitzen

# Extrem Werte als NaN behandeln
df.loc[df["price"] > upper_cap, "price"] = np.nan

# %%
# Hierarchische Median-Imputation (fein)
groupings = [
    ["neighbourhood_group_cleansed","room_type","accommodates"],
    ["neighbourhood_group_cleansed","room_type"],
    ["room_type","accommodates"],
    ["room_type"],
]
for cols in groupings:
    cols = [c for c in cols if c in df.columns]
    if not cols: 
        continue
    med = df.groupby(cols)["price"].transform("median")
    need = df["price"].isna() & med.notna()
    df.loc[need, "price"] = med[need]

# Fallback: globaler Median  (grob)
# if df["price"].isna().any():
#     df["price"] = df["price"].fillna(df["price"].median())

# Check
print("Missing price after imputation:", df["price"].isna().sum())
# Out:
# Missing price after imputation: 0

# %% [markdown]
# ### Spalte "bathrooms" bereinigen und fehlende Werte aus "bathrooms_text" füllen
#
# **Fehlende Werte** 40.3%
#
# **Ziel:** Die numerische Spalte **`bathrooms`** (float) vervollständigen, indem wir fehlende Werte aus der textuellen Spalte **`bathrooms_text`** ableiten. Beide Felder beschreiben dieselbe Information.
#
# **Vorgehen:**
# 1. **Parsing-Regeln:**
#    - Zahl direkt vor *bath/bathrooms* (z. B. `1 bath`, `1.5 baths`, `2 bathrooms`, `0 baths`).
#    - *half-bath* ohne Zahl ist gleich **0.5**.
#    - Zusätze wie *private/shared* werden ignoriert.
# 2. **Füllen:** Nur dort ergänzen, wo `bathrooms` **NaN** ist – existierende numerische Werte werden **nicht** überschrieben.
# 3. **Check:** Wie viele Zeilen gefüllt, wie viele fehlen noch.

# %%
df[df["bathrooms"].notna()][["bathrooms", "bathrooms_text"]].head(10)
# Out:
#     bathrooms    bathrooms_text
# 0         1.0    1 private bath
# 1         1.0            1 bath
# 2         1.5         1.5 baths
# 3         1.0            1 bath
# 5         1.0     1 shared bath
# 7         1.0    1 private bath
# 8         1.0            1 bath
# 11        1.0            1 bath
# 14        1.0            1 bath
# 16        1.5  1.5 shared baths

# %%
# Investigate
df["bathrooms"].unique()
# Out:
# array([ 1. ,  1.5,  nan,  2. ,  2.5,  3. ,  5. ,  0. ,  0.5,  3.5, 15.5,
#        10.5,  4. ,  4.5,  5.5,  6. ,  7. ,  7.5,  9. ,  6.5])

# %%
# Investigate
df["bathrooms_text"].unique()
# Out:
# array(['1 private bath', '1 bath', '1.5 baths', '1 shared bath',
#        '1.5 shared baths', '2 baths', '2.5 baths', nan, '3 baths',
#        '5 baths', '0 shared baths', '2 shared baths', 'Shared half-bath',
#        '3.5 baths', '2.5 shared baths', 'Half-bath', 'Private half-bath',
#        '0 baths', '15.5 baths', '3 shared baths', '10.5 baths', '4 baths',
#        '4.5 baths', '3.5 shared baths', '4 shared baths',
#        '4.5 shared baths', '5.5 baths', '6 baths', '7 baths',
#        '6 shared baths', '7.5 baths', '9 baths', '5 shared baths',
#        '6.5 baths'], dtype=object)

# %%
# Investigate: "bathrooms", "bathrooms_text"
df_bathrooms_null_bathrooms_text = df[df["bathrooms"].isnull()][["bathrooms", "bathrooms_text"]]

df_bathrooms_null_bathrooms_text.head(10)
# df_bathrooms_null_bathrooms_text.index.values

idx = df_bathrooms_null_bathrooms_text.index.values

# %%
# fill df["bathrooms"] from df["bathrooms_text"] only where it’s missing 
# (handles “1 bath”, “1.5 baths”, “Half-bath”, “shared half-bath”, “2 bathrooms”, etc.):
 
pattern = re.compile(r"""(?ix)
    ^\s*                                                          # allow leading spaces
    (?:                                                           # start alternation
        (?P<num>\d+(?:\.\d+)?)\s*                                 # 1, 1.5, 0, 15.5
        (?: (?:private|shared)\s+ )?                              # optional qualifier after number
        bath(?:room)?s?                                           # bath / bathroom(s)
      |
        (?: (?:private|shared)\s+ )?                              # optional qualifier before 'half'
        half[-\s]?bath(?:room)?s?                                 # half-bath / half bathroom(s)
    )
    \s*$                                                          # allow trailing spaces
""")

def parse_bath(text: str):
    """Parse bath count from bathrooms_text (your listed formats)."""
    if not isinstance(text, str) or not text.strip():
        return np.nan
    m = pattern.match(text.strip())
    if not m:
        return np.nan
    if m.group('num') is not None:        # numeric forms: '1 bath', '1.5 shared baths', '0 baths'
        return float(m.group('num'))
    else:                                  # 'half-bath', 'shared half-bath', 'private half-bath'
        return 0.5

# fill only missing bathrooms from parsed bathrooms_text
df["bathrooms"] = df["bathrooms"].fillna(df["bathrooms_text"].apply(parse_bath))

# %%
# Missing values
df["bathrooms"].isna().sum()
# Out:
# np.int64(25)

# %%
df["bathrooms"].unique()
# Out:
# array([ 1. ,  1.5,  2. ,  2.5,  nan,  3. ,  5. ,  0. ,  0.5,  3.5, 15.5,
#        10.5,  4. ,  4.5,  5.5,  6. ,  7. ,  7.5,  9. ,  6.5])

# %%
df_bathrooms_null_bathrooms_text_filled = df[df["bathrooms"].isnull()][["bathrooms", "bathrooms_text"]]

len(df_bathrooms_null_bathrooms_text_filled)
# Out:
# 25

# %%
df_bathrooms_null_bathrooms_text_filled.index.values
# Out:
# array([   59,   389,   443,   457,   469,   828,   849,  2347,  2503,
#         3018,  5822, 14940, 17366, 17367, 17381, 20029, 20054, 20057,
#        28437, 30861, 33572, 34513, 34973, 35625, 35811])

# %%
df = df.drop("bathrooms_text", axis=1)

# %% [markdown]
# ### Spalte "host_neighbourhood" und "host_location" untersuchen
#
# **Fehlende Werte** > 20%
#
# **Ziel:** Die Spalte **`host_neighbourhood`** und **host_location** aufbereiten.
#
# **Vorgehen:**
#
# - **Daten:** `host_neighbourhood` mit `neighbourhood_cleansed` vergleichen.
# - **Daten:** `host_neighbourhood` dropen.
# - **Daten:** `host_location` mit `atitude` und `longitude` vergleichen.
# - **Daten:** `host_location` dropen.

# %%
# No description in the data Doctionary:

df["host_neighbourhood"].unique()[:10]

# array(['Gravesend', 'Midtown', 'Greenwood Heights', 'Williamsburg',
#        'East Harlem', 'Fort Greene', 'Ridgewood', 'Alphabet City',
#        'Greenwich Village', 'Harlem', ...], dtype=object)
# Out:
# array(['Gravesend', 'Midtown', 'Greenwood Heights', 'Williamsburg',
#        'East Harlem', 'Fort Greene', 'Ridgewood', 'Alphabet City',
#        'Greenwich Village', 'Harlem'], dtype=object)

# %%
df[df["host_neighbourhood"].notnull()][["host_neighbourhood", "neighbourhood_cleansed"]].head(10)
# Out:
#   host_neighbourhood neighbourhood_cleansed
# 0          Gravesend             Kensington
# 1            Midtown                Midtown
# 2  Greenwood Heights            Sunset Park
# 3       Williamsburg           Williamsburg
# 4        East Harlem            East Harlem
# 5        East Harlem            East Harlem
# 6       Williamsburg           Williamsburg
# 7        Fort Greene            Fort Greene
# 8          Ridgewood              Ridgewood
# 9      Alphabet City           East Village

# %%
len(df[df["host_neighbourhood"] == df["neighbourhood_cleansed"]][["host_neighbourhood", "neighbourhood_cleansed"]])
# Out:
# 16173

# %%
len(df[df["host_neighbourhood"] != df["neighbourhood_cleansed"]][["host_neighbourhood", "neighbourhood_cleansed"]])
# Out:
# 20149

# %%
# Drop "host_neighbourhood". The reason: we have a column "neighbourhood_cleansed" with correct location
df = df.drop("host_neighbourhood", axis=1)

# %%
# Description in the data Doctionary: The host's self reported location
df["host_location"].unique()[:10]

# array(['New York, NY', 'Woodstock, NY', ...])
# Out:
# array(['New York, NY', 'Woodstock, NY', 'Las Vegas, NV',
#        'New York, United States', 'Great Neck, NY', 'Berkeley, CA',
#        'Los Angeles, CA', nan, 'Montreal, Canada', 'United States'],
#       dtype=object)

# %%
# Compare the column "host_location" with "latitude" and "longitude"
df[df["host_location"].notnull()][["host_location", "latitude", "longitude"]].head(10)
# Out:
#    host_location  latitude  longitude
# 0   New York, NY  40.64529  -73.97238
# 1  Woodstock, NY  40.75356  -73.98559
# 2   New York, NY  40.66265  -73.99454
# 3   New York, NY  40.70935  -73.95342
# 4   New York, NY  40.80107  -73.94255
# 5   New York, NY  40.78778  -73.94759
# 6   New York, NY  40.71248  -73.95881
# 7   New York, NY  40.69194  -73.97389
# 8   New York, NY  40.70271  -73.89930
# 9   New York, NY  40.72530  -73.98028

# %%
# Investigate the column "host_location"
# Convert type df["host_location"] to string
df["host_location"] = df["host_location"].astype("string") 

df[df["host_location"] == "Calgary, Canada"][["host_location", "latitude", "longitude"]]
#         host_location	latitude	longitude
# 34152	Calgary, Canada	40.678622	-73.946671
# BUT IT'S NY !!!!

df[df["host_location"] == "Vila Velha, Brazil"][["host_location", "latitude", "longitude"]]
#         host_location	latitude	longitude
# 35999	Vila Velha, Brazil	40.730115	-73.982319
# BUT IT'S NY !!!!
# Out:
#             host_location   latitude  longitude
# 35999  Vila Velha, Brazil  40.730115 -73.982319

# %%
# Drop "host_location" - a lot of redundant data
df = df.drop("host_location", axis=1)

# %% [markdown]
# ### Spalte "has_availability" untersuchen und fehlende Werte aus "availability_365" füllen
#
# **Fehlende Werte** 15%
#
# **Ziel:** Die boolische Spalte **`has_availability`** vervollständigen, indem wir fehlende Werte aus der Spalte **`availability_365`** ableiten.
#
# **Vorgehen:**
# 1. **Füllen:** Nur dort ergänzen, wo `has_availability` **NaN** ist – existierende boolische Werte werden **nicht** überschrieben.
# 2. **Check:** Wie viele Zeilen gefüllt, wie viele fehlen noch.

# %%
print("Missing \"has_availability\" before:", df["has_availability"].isna().sum())
# Out:
# Missing "has_availability" before: 5617

# %%
# Investigate "has_availability "
df["has_availability"].unique()
# >>>
# <BooleanArray>
# [True, <NA>]
# Length: 2, dtype: boolean

df[df["has_availability"].isnull()][["has_availability", "availability_30", "availability_60", "availability_90", "availability_365"]]
# >>>
#        has_availability	availability_30	availability_60	availability_90	availability_365
# 13	<NA>	0	0	0	0
# 35	<NA>	0	0	0	0
# 42	<NA>	0	0	0	0
# 59	<NA>	0	0	0	0
# 71	<NA>	0	0	0	0
# ...	...	...	...	...	...
# 36268	<NA>	28	58	88	88
# 36273	<NA>	6	21	51	141
# 36276	<NA>	30	60	90	365
# 36306	<NA>	16	46	66	66
# 36311	<NA>	10	31	31	31

# len(df[df["availability_30"] == 0][df["availability_60"] == 0][df["availability_90"] == 0][df["availability_365"] == 0][["has_availability"]])

mask = (
    df["availability_30"].eq(0) &
    df["availability_60"].eq(0) &
    df["availability_90"].eq(0) &
    df["availability_365"].eq(0) &
    df["has_availability"].isna()
)

count = mask.sum()          # number of rows
rows  = df.loc[mask]        # the matching rows (if you need them)
count
rows[["has_availability","availability_30","availability_60","availability_90","availability_365"]]
# Out:
#        has_availability  availability_30  availability_60  availability_90  \
# 13                 <NA>                0                0                0
# 35                 <NA>                0                0                0
# 42                 <NA>                0                0                0
# 59                 <NA>                0                0                0
# 71                 <NA>                0                0                0
# ...                 ...              ...              ...              ...
# 33888              <NA>                0                0                0
# 33982              <NA>                0                0                0
# 34117              <NA>                0                0                0
# 34294              <NA>                0                0                0
# 36088              <NA>                0                0                0
#
#        availability_365
# 13                    0
# 35                    0
# 42                    0
# 59                    0
# 71                    0
# ...                 ...
# 33888                 0
# 33982                 0
# 34117                 0
# 34294                 0
# 36088                 0
#
# [5348 rows x 5 columns]

# %%
mask = (
    df["has_availability"].isna() |
    df["availability_30"].eq(0) &
    df["availability_60"].eq(0) &
    df["availability_90"].eq(0) &
    df["availability_365"].eq(0)
)

count = mask.sum()          # number of rows
rows  = df.loc[mask]        # the matching rows (if you need them)
count
rows[["has_availability","availability_30","availability_60","availability_90","availability_365"]]
# Out:
#        has_availability  availability_30  availability_60  availability_90  \
# 6                  True                0                0                0
# 9                  True                0                0                0
# 10                 True                0                0                0
# 13                 <NA>                0                0                0
# 15                 True                0                0                0
# ...                 ...              ...              ...              ...
# 36268              <NA>               28               58               88
# 36273              <NA>                6               21               51
# 36276              <NA>               30               60               90
# 36306              <NA>               16               46               66
# 36311              <NA>               10               31               31
#
#        availability_365
# 6                     0
# 9                     0
# 10                    0
# 13                    0
# 15                    0
# ...                 ...
# 36268                88
# 36273               141
# 36276               365
# 36306                66
# 36311                31
#
# [12650 rows x 5 columns]

# %%
# Clean df["has_availability"]
# Minimal (use 365 days only)
# fill the 15% missing in has_availability: True if there is at least 1 available day in the next 365, else False
df["has_availability"] = (
    df["has_availability"]
      .fillna(df["availability_365"].gt(0))
      .astype("boolean")
)

# %%
print("Missing \"has_availability\" after:", df["has_availability"].isna().sum())
# Out:
# Missing "has_availability" after: 0

# %%
missing_values(df)[missing["Total_perc"] > 0].Total_perc
# Out:
# name                            0.005506
# host_since                      0.041297
# host_acceptance_rate           40.201531
# host_verifications              0.041297
# host_identity_verified          0.041297
# bathrooms                       0.068829
# bedrooms                       16.651065
# beds                           40.476846
# estimated_revenue_l365d        40.920104
# first_review                   30.700402
# last_review                    30.700402
# review_scores_rating           30.700402
# review_scores_accuracy         30.727933
# review_scores_cleanliness      30.703155
# review_scores_checkin          30.738946
# review_scores_communication    30.716921
# review_scores_location         30.747206
# review_scores_value            30.744452
# license                        85.328451
# reviews_per_month              30.700402
# Name: Total_perc, dtype: float64

# %% [markdown]
# ### Spalte "estimated_revenue_l365d", "host_acceptance_rate" und "beds" untersuchen
#
# **Fehlende Werte** > 40%
#
# **Ziel:** Die Spalte **`estimated_revenue_l365d`**, **host_acceptance_rate** und **bads** aufbereiten.
#
# **Vorgehen:**
#
# - **Daten:** `estimated_revenue_l365d` dropen.
# - **Daten:** `host_acceptance_rate` dropen.
# - **Daten:** `bads` dropen.

# %%
# Investigate: not in the dictionary !!!!!
len(df["estimated_revenue_l365d"].unique())
# Out:
# 2442

# %%
# Drop "estimated_revenue_l365d"
df = df.drop("estimated_revenue_l365d", axis=1)

# %%
# Investigate 
# "bedrooms" missing values 16.651065
# "beds": missing values 40.476846
# mask = (
#     df["beds"].eq(0) &
#     df["bedrooms"].eq(0)
# )

# count = mask.sum()  
# count
# rows  = df.loc[mask] 
# rows[["beds", "bedrooms"]]
# 60

# mask = (
#     df["beds"].isnull() &
#     df["bedrooms"].notnull()
# )
# mask = (
#     df["beds"].notnull() &
#     df["bedrooms"].notnull() &
#     df["beds"] > df["bedrooms"]
# )
# rows  = df.loc[mask]
# len(rows)*100/len(df) # 24 %

# Let's drop "beds" - viel missing data
df = df.drop("beds", axis=1)

# %%
# Do not need for statistic: drop "host_acceptance_rate"
df = df.drop("host_acceptance_rate", axis=1)

# %% [markdown]
# ### Spalten`first_review` & `last_review` bereinigen und fehlende Werte ausfüllen
#
# **Fehlende Werte** > 30%
#
# **Ziel:** Die Datumsfelder **`first_review`** und **`last_review`** in **`datetime64[ns]`** konvertieren, **Ausreißer** (Zukunft/Extremwerte) entfernen und **fehlende Werte** mit dem **globalen Median-Datum** pro Spalte füllen.
#
# **Vorgehen:**
# - **Datumsformat:** in `datetime64[ns]` umwandeln.
# - **Offensichtliche Ausreißer:**
#   - **Zukunftsdaten** (`> heute`) -> `NaT`.
#   - **Sehr späte Werte** (z. B. > **99,5%-Quantil**) -> `NaT`.
#   - **Sehr frühe Werte** (< 0,5%-Quantil) -> `NaT`.
# - **Konsistenz:** sicherstellen, dass `first_review ≤ last_review`; sonst inkonsistente Werte auf `NaT`.
# - **Check vor Imputation:** Verteilungen/Anteil Missing prüfen.
# - **Imputation:** **globaler Median** je Spalte (`first_review`, `last_review`) zum Füllen von `NaT`.
# - **Check nach Imputation:** Verteilungen/Kennzahlen erneut prüfen; Anteil imputierter Werte dokumentieren.

# %%
# Check missing values
date_cols = ["first_review", "last_review"]

for c in date_cols:
    print("Missing values before imputation:", df[c].isna().sum())
# Out:
# Missing values before imputation: 11151
# Missing values before imputation: 11151

# %%
# Datums-Extremwerte (einfach) -> NaT, dann mit Median füllen
date_cols = ["first_review", "last_review"]

for c in date_cols:
    s = pd.to_datetime(df[c], errors="coerce")

    # Offensichtliche Ausreißer -> NaT
    s = s.mask(s > pd.Timestamp.today())      # Zukunftsdaten
    upper_cap = s.quantile(0.995)             # sehr späte Ausreißer (oberes 99,5%-Quantil)
    s = s.mask(s > upper_cap)

    # Sehr frühe Ausreißer
    lower_cap = s.quantile(0.005)
    s = s.mask(s < lower_cap)

# %%
# Konsistenz prüfen: first_review <= last_review, sonst konservativ auf NaT setzen

both = df["first_review"].notna() & df["last_review"].notna()
bad = both & (df["first_review"] > df["last_review"])
if bad.any():
    df.loc[bad, ["first_review", "last_review"]] = pd.NaT

# %%
# Missing mit globalem Median-Datum füllen

for c in ["first_review", "last_review"]:
    df[c] = pd.to_datetime(df[c], errors="coerce")  # -> datetime64[ns]
    med = df[c].median()                            # Timestamp
    df[c] = df[c].fillna(med)                       # fill NaT with median

# %%
# Check missing values

for c in date_cols:
    print("Missing values after imputation:", df[c].isna().sum())
# Out:
# Missing values after imputation: 0
# Missing values after imputation: 0

# %%
missing_values(df)[missing["Total_perc"] > 0].Total_perc
# Out:
# name                            0.005506
# host_since                      0.041297
# host_verifications              0.041297
# host_identity_verified          0.041297
# bathrooms                       0.068829
# bedrooms                       16.651065
# review_scores_rating           30.700402
# review_scores_accuracy         30.727933
# review_scores_cleanliness      30.703155
# review_scores_checkin          30.738946
# review_scores_communication    30.716921
# review_scores_location         30.747206
# review_scores_value            30.744452
# license                        85.328451
# reviews_per_month              30.700402
# Name: Total_perc, dtype: float64

# %% [markdown]
# ### Spalten `review_*` und `reviews_*` bereinigen und fehlende Werte ausfüllen
#
# **Fehlende Werte** > 30%
#
# **Ziel:** Alle numerischen Review-Spalten (z. B. `review_scores_rating`, `review_scores_cleanliness`, `reviews_per_month`) konsistent säubern, **Ausreißer** entfernen und **fehlende Werte** robust mit dem **spaltenspezifischen Median** füllen.
#
# **Auswahl der Spalten:**
# - `view_cols = [c for c in df.columns if c.lower().startswith(("review_", "reviews_"))]`
#
# **Vorgehen:**
# - **Typkonvertierung:** ausgewählte Spalten in **float** konvertieren.
# - **Offensichtliche Fehler:** **negative Werte** -> `NaN`.
# - **Ausreißer (hoch):** Werte **> 99,5%-Quantil** pro Spalte -> `NaN`.
# - **Ausreißer (niedrig):** Werte **< 0,5%-Quantil** -> `NaN`.
# - **Check vor Imputation:** Verteilungen/Anteil Missing je Spalte prüfen.
# - **Imputation:** fehlende Werte **spaltenweise** mit dem **Median** füllen.
# - **Check nach Imputation:** Verteilungen und Anteil imputierter Werte dokumentieren; sicherstellen, dass keine negativen/außerhalb-Bereich-Werte verbleiben.

# %%
# Check missing values
review_cols = [c for c in df.columns if c.lower().startswith(("review_", "reviews_"))]

for c in review_cols:
    print("Missing values before imputation:", df[c].isna().sum())
# Out:
# Missing values before imputation: 11151
# Missing values before imputation: 11161
# Missing values before imputation: 11152
# Missing values before imputation: 11165
# Missing values before imputation: 11157
# Missing values before imputation: 11168
# Missing values before imputation: 11167
# Missing values before imputation: 11151

# %%
# Datums-Extremwerte -> NaT, dann mit Median füllen

for c in review_cols:
    # zu float konvertieren
    s = pd.to_numeric(df[c], errors="coerce")

    # offensichtliche Fehler/Ausreißer -> NaN
    s = s.mask(s < 0)                 # negative Werte nicht zulässig
    upper_cap = s.quantile(0.995)     # sehr hohe Spitzen kappen
    s = s.mask(s > upper_cap)

    # Sehr niedrige Ausreißer kappen
    lower_cap = s.quantile(0.005)
    s = s.mask(s < lower_cap)

    # fehlende Werte mit Median füllen
    df[c] = s.fillna(s.median())

# %%
# Check missing values

for c in review_cols:
    print("Missing values before imputation:", df[c].isna().sum())
# Out:
# Missing values before imputation: 0
# Missing values before imputation: 0
# Missing values before imputation: 0
# Missing values before imputation: 0
# Missing values before imputation: 0
# Missing values before imputation: 0
# Missing values before imputation: 0
# Missing values before imputation: 0

# %% [markdown]
# ### Spalten mit Fehlende Werte bereinigen und fehlende Werte ausfüllen
#
# - **`name`**: trimmen von Leerzeichen; fehlend -> **„Unbenannt“**.
# - **`host_since`**: Zukunft und >99,5%-Quantil -> `NaT`; fehlend -> **Median-Datum**.
# - **`host_verifications`**: fehlend -> `"[]"`; trimmen.
# - **`host_identity_verified`**: fehlend -> **False**.
# - **`bathrooms`**: gruppierter **Median** nach `room_type × accommodates`, sonst global; `≥0` clippen, auf **0,5** runden.
# - **`bedrooms`**: gruppierter **Median**, sonst global; `≥0` clippen.
# - **`license`**: wegen sehr hoher Missing-Rate **droppen**.
# - **Report**: verbleibende Missing je Spalte ausgeben.

# %%
# Spalten mit Fehlende Werte

missing_values(df)[missing["Total_perc"] > 0].Total_perc
# Out:
# name                       0.005506
# host_since                 0.041297
# host_verifications         0.041297
# host_identity_verified     0.041297
# bathrooms                  0.068829
# bedrooms                  16.651065
# license                   85.328451
# Name: Total_perc, dtype: float64

# %%
# Spalte: "name"

df["name"] = df["name"].str.strip().fillna("Unbenannt")

# %%
# Spalte: "license" (sehr hohe Missing-Rate 85%)

df["license"] = df["license"].str.strip().fillna("Unbenannt")

# %%
# Spalte: "host_since"
s = df["host_since"]
s = s.mask(s > pd.Timestamp.today())              # Zukunft → NaT
upper_cap = s.quantile(0.995)                     # sehr späte Ausreißer
s = s.mask(s > upper_cap)
df["host_since"] = s.fillna(s.median())           # globaler Median pro Spalte

# %%
# Spalte: "host_verifications"

df["host_verifications"] = df["host_verifications"].fillna("[]").str.strip()

# %%
# Spalte: "host_identity_verified"

df["host_identity_verified"] = df["host_identity_verified"].fillna(False)

# %%
# Spalte: "bathrooms"

grp_cols = [c for c in ["room_type","accommodates"] if c in df.columns]
if grp_cols:
    med_g = df.groupby(grp_cols)["bathrooms"].transform("median")
    need = df["bathrooms"].isna()
    df.loc[need, "bathrooms"] = med_g[need]
# Fallback global
df["bathrooms"] = df["bathrooms"].fillna(df["bathrooms"].median())
 # Aufräumen
df["bathrooms"] = df["bathrooms"].clip(lower=0)
df["bathrooms"] = (np.round(df["bathrooms"] * 2) / 2)  # 0.5-Schritte

# %%
# Spalte: "bedrooms"

grp_cols = [c for c in ["room_type","accommodates"] if c in df.columns]
if grp_cols:
    med_g = df.groupby(grp_cols)["bedrooms"].transform("median")
    need = df["bedrooms"].isna()
    df.loc[need, "bedrooms"] = med_g[need]
df["bedrooms"] = df["bedrooms"].fillna(df["bedrooms"].median())
df["bedrooms"] = df["bedrooms"].clip(lower=0)

# %%
# Check
cols_report = ["name","host_since","host_verifications","host_identity_verified","bathrooms","bedrooms","license"]
present = [c for c in cols_report if c in df.columns]
print("Bereinigte Spalten:", present)
print(df[present].isna().sum().sort_values(ascending=False))
# Out:
# Bereinigte Spalten: ['name', 'host_since', 'host_verifications', 'host_identity_verified', 'bathrooms', 'bedrooms', 'license']
# name                      0
# host_since                0
# host_verifications        0
# host_identity_verified    0
# bathrooms                 0
# bedrooms                  0
# license                   0
# dtype: int64

# %%
missing_values(df)[missing["Total_perc"] > 0].Total_perc
# Out:
# Series([], Name: Total_perc, dtype: float64)

# %% [markdown]
# ### Feature Engineering: `host_since_year` aus `host_since`
#
# *Ziel:* Jahr für einfache Gruppierungen/Trends ableiten.
# *Voraussetzung:* `host_since` ist bereits `datetime64[ns]`.

# %%
df["host_since"].head()
# Out:
# 0   2008-09-07
# 1   2008-09-09
# 2   2009-02-03
# 3   2009-05-06
# 4   2009-05-07
# Name: host_since, dtype: datetime64[ns]

# %%
# extract year from "host_since"
    
df["host_since_year"] = df["host_since"].dt.year.astype("int64")

# %%
df["host_since_year"].head()
# Out:
# 0    2008
# 1    2008
# 2    2009
# 3    2009
# 4    2009
# Name: host_since_year, dtype: int64

# %%
# Save dataframe to csv file
df.to_csv(f"{file[:-4]}_clean.csv")
