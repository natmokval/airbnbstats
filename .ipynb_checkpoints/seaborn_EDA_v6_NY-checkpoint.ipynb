# %%
# %pip install seaborn
# %pip install matplotlib

# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
file = "data/12/NewYorkCity/listings_big_clean.csv" 

df = pd.read_csv(file, low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36322 entries, 0 to 36321
# Data columns (total 49 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    36322 non-null  int64
#  1   id                            36322 non-null  int64
#  2   name                          36322 non-null  object
#  3   host_since                    36322 non-null  object
#  4   host_verifications            36322 non-null  object
#  5   host_identity_verified        36322 non-null  bool
#  6   neighbourhood_cleansed        36322 non-null  object
#  7   neighbourhood_group_cleansed  36322 non-null  object
#  8   latitude                      36322 non-null  float64
#  9   longitude                     36322 non-null  float64
#  10  property_type                 36322 non-null  object
#  11  room_type                     36322 non-null  object
# ...

# %%
# Create a histogram of the room_type amounts

sns.histplot(data=df, x="room_type")
# Out:
# <Axes: xlabel='room_type', ylabel='Count'>

# %%
# Create a histogram of the availability_365 amounts

sns.histplot(data=df, x="availability_365")
# Out:
# <Axes: xlabel='availability_365', ylabel='Count'>

# %%
# Create a histogram of the neighbourhood_group_cleansed amounts

sns.histplot(data=df, x="neighbourhood_group_cleansed")
# Out:
# <Axes: xlabel='neighbourhood_group_cleansed', ylabel='Count'>

# %%
sns.scatterplot(x="neighbourhood_group_cleansed", y="price", data=df)
# Out:
# <Axes: xlabel='neighbourhood_group_cleansed', ylabel='price'>

# %%
sns.scatterplot(x="room_type", y="number_of_reviews", data=df)
# Out:
# <Axes: xlabel='room_type', ylabel='number_of_reviews'>

# %%
# customize the scatter plot

sns.scatterplot(x="number_of_reviews", y="host_since_year", hue="neighbourhood_group_cleansed", data=df)

# add labels and title

plt.xlabel("number_of_reviews")

plt.ylabel("host_since")

plt.title("Relationship between host_since_year and number_of_reviews_ly")

# display the plot

plt.show()

# %%
mask = df["price"] < 4000
sns.boxplot(x="neighbourhood_group_cleansed", y="price", hue="instant_bookable", data=df[mask], palette="Set3", linewidth=1.5, fliersize=4)

# add a title, xlabel, and ylabel to the plot using Matplotlib functions

plt.title("Box Plot of Price by Neighbourhood_group and instant_bookable")

plt.xlabel("Neighbourhood_group")

plt.ylabel("Price")

# display the plot

plt.show()

# %%
df["price"].max()
# Out:
# np.float64(40000.0)

# %%
df["price"].min()
# Out:
# np.float64(8.0)

# %%
# sns.lineplot(x="price", y="neighbourhood_group_cleansed", data=df)

# %%
# Create a heatmap of the correlation between variables

corr = df.corr(numeric_only=True)

sns.heatmap(corr, annot=True)

# Show the plot

plt.show()

# %%
df_numeric = df.select_dtypes(include='number')

df_numeric.head()
# Out:
#    Unnamed: 0    id  latitude  longitude  accommodates  bathrooms  bedrooms  \
# 0           0  2539  40.64529  -73.97238             2        1.0       1.0
# 1           1  2595  40.75356  -73.98559             1        1.0       0.0
# 2           2  5136  40.66265  -73.99454             4        1.5       2.0
# 3           3  6848  40.70935  -73.95342             3        1.0       2.0
# 4           4  6872  40.80107  -73.94255             1        1.0       1.0
#
#    price  minimum_nights  maximum_nights  ...  estimated_occupancy_l365d  \
# 0  285.0              30             730  ...                          0
# 1  240.0              30            1125  ...                          0
# 2  215.0              30             730  ...                          0
# 3   97.0              30             120  ...                        240
# 4   80.0              30             180  ...                          0
#
# ...

# %%
sns.histplot(df_numeric['host_since_year'], bins=50, kde=True)
# Out:
# <Axes: xlabel='host_since_year', ylabel='Count'>

# %%
#select non-numeric variables
df_non_numeric = df.select_dtypes(exclude='number')

print(df_non_numeric.info())


plt.figure(figsize=(25,7))
plt.xticks(rotation=70)

sns.countplot(x="neighbourhood_group_cleansed", data=df_non_numeric)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36322 entries, 0 to 36321
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          36322 non-null  object
#  1   host_since                    36322 non-null  object
#  2   host_verifications            36322 non-null  object
#  3   host_identity_verified        36322 non-null  bool
#  4   neighbourhood_cleansed        36322 non-null  object
#  5   neighbourhood_group_cleansed  36322 non-null  object
#  6   property_type                 36322 non-null  object
#  7   room_type                     36322 non-null  object
#  8   amenities                     36322 non-null  object
#  9   has_availability              36322 non-null  bool
#  10  first_review                  36322 non-null  object
#  11  last_review                   36322 non-null  object
# ...
